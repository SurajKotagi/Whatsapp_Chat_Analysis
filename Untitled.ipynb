# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with adarsh.txt', 'r', encoding = 'utf-8')

# %%
data = f.read()
print(data)
# Out:
# 20/03/22, 12:25 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 20/03/22, 12:25 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 12:25 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 12:26 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 12:26 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 12:26 pm - 🍀 ADARSH: Still some are there but they are not under offer
# 20/03/22, 12:26 pm - SURAJ 🍁: wiat
# 20/03/22, 12:26 pm - SURAJ 🍁: wait
# 20/03/22, 12:27 pm - 🍀 ADARSH: The brand I ordered was priced high & under no offer
# 20/03/22, 12:27 pm - 🍀 ADARSH: Black shirts are aren't under offer
# 20/03/22, 12:30 pm - SURAJ 🍁: tattoo on his hand are killer 😅
# 20/03/22, 12:31 pm - 🍀 ADARSH: Yeah yeah !!
# 20/03/22, 12:31 pm - SURAJ 🍁: https://www.ajio.com/netplay-checked-shirt-with-patch-pocket/p/441123883_white
# 20/03/22, 12:33 pm - SURAJ 🍁: https://www.ajio.com/netplay-checked-shirt-with-patch-pocket/p/441123884_navy
# 20/03/22, 12:44 pm - 🍀 ADARSH: Wich one do you want 😂😂
# 20/03/22, 12:44 pm - 🍀 ADARSH: Or both !?
# 20/03/22, 12:44 pm - SURAJ 🍁: both👍🏻
# 20/03/22, 12:44 pm - 🍀 ADARSH: Alright let me check for a min
# 20/03/22, 12:44 pm - SURAJ 🍁: approx 300 each they are
# 20/03/22, 12:45 pm - 🍀 ADARSH: Yes yes !!
# 20/03/22, 12:45 pm - 🍀 ADARSH: What about size btw
# 20/03/22, 12:45 pm - SURAJ 🍁: i will check n send you wait
# 20/03/22, 12:45 pm - 🍀 ADARSH: Alright
# 20/03/22, 12:45 pm - SURAJ 🍁: offer is till what time
# 20/03/22, 12:46 pm - 🍀 ADARSH: Today evening or night maxx
# 20/03/22, 12:46 pm - SURAJ 🍁: asap i will send
# 20/03/22, 12:46 pm - 🍀 ADARSH: Alright
# 20/03/22, 1:07 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 1:24 pm - SURAJ 🍁: horag adeni ,gapp
# 20/03/22, 3:09 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 3:09 pm - SURAJ 🍁: https://www.ajio.com/netplay-checked-shirt-with-patch-pocket/p/441119265_white
# 20/03/22, 3:10 pm - SURAJ 🍁: https://www.ajio.com/netplay-checked-cotton-shirt-with-patch-pocket/p/441123873_white
# 20/03/22, 3:13 pm - SURAJ 🍁: https://www.ajio.com/netplay-checked-cotton-shirt/p/441114059_mediumblue
# 20/03/22, 3:14 pm - SURAJ 🍁: https://www.ajio.com/netplay-checked-cotton-shirt/p/441114059_copper
# 20/03/22, 3:14 pm - SURAJ 🍁: 1
# 20/03/22, 3:15 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 3:17 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 3:18 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 3:39 pm - SURAJ 🍁: <Media omitted>
# 20/03/22, 3:39 pm - SURAJ 🍁: <Media omitted>
# 20/03/22, 3:40 pm - SURAJ 🍁: https://www.ajio.com/netplay-striped-shirt-with-patch-pocket/p/441123936_rust
# 20/03/22, 3:42 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 3:43 pm - SURAJ 🍁: <Media omitted>
# 20/03/22, 3:50 pm - SURAJ 🍁: <Media omitted>
# 20/03/22, 3:52 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 3:59 pm - 🍀 ADARSH: I recently tried CashKaro.com & highly recommend it! You get extra Cashback on top of all retailer discounts.
#  Try it out: https://cashk.app.link/lao8Cfn4xob
# 20/03/22, 4:01 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 4:02 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 4:02 pm - SURAJ 🍁: Limited-time deal: Fur Jaden Navy Casual Backpack with USB Charging Port and 15.6 Inch Laptop Pocket https://www.amazon.in/dp/B07G4G3NPD/ref=cm_sw_r_apan_glt_i_dl_MYT1JFKWSFGKT6FJAFNB?_encoding=UTF8&psc=1
# 20/03/22, 8:07 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 9:19 pm - SURAJ 🍁: listy=["red","green","blue".....]
# my_colour = listy[int(random(10))]
# k = 1
# while(k)
#     k = True
#     my_colour = listy[int(random(10))]
#     user_color = str(input("guess a color : "))
#     if(user_color == my_colour)
#         print("yahoo same colour")
#     elif(user_color == "no")
#         k = False
#     else
#         print("nadi manig not same color")
# 20/03/22, 9:33 pm - 🍀 ADARSH: print('you are a holy stud')
# 20/03/22, 9:34 pm - SURAJ 🍁: while(True)
#    print (" you are also ")
# 20/03/22, 9:35 pm - 🍀 ADARSH: Yeah yeah !! Whatever 😂😂
# 20/03/22, 9:35 pm - SURAJ 🍁: 😁
# 20/03/22, 9:37 pm - 🍀 ADARSH: Bankacnum=int(input("enter the number linked with phonepe or whatever kind of pay ")
# 20/03/22, 9:37 pm - 🍀 ADARSH: Imma launch some money
# 20/03/22, 9:37 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 9:38 pm - SURAJ 🍁: use long long int
# 20/03/22, 9:39 pm - 🍀 ADARSH: Eee hatroo
# 20/03/22, 9:39 pm - 🍀 ADARSH: Python
# 20/03/22, 9:39 pm - SURAJ 🍁: 😅
# 20/03/22, 9:39 pm - 🍀 ADARSH: Number hel ig 😂😂
# 20/03/22, 9:39 pm - 🍀 ADARSH: For this reason
# 20/03/22, 9:39 pm - SURAJ 🍁: 8197344704
# 20/03/22, 9:41 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 9:41 pm - 🍀 ADARSH: <Media omitted>
# 20/03/22, 10:08 pm - SURAJ 🍁: 👍🏻
# 21/03/22, 12:28 pm - SURAJ 🍁: <Media omitted>
# 21/03/22, 12:29 pm - SURAJ 🍁: <Media omitted>
# 21/03/22, 2:52 pm - 🍀 ADARSH: I chewed the veggies & food slowly & completely and it took about entire 1 hr
# 21/03/22, 6:24 pm - SURAJ 🍁: 😅 any benifits you seen?
# 21/03/22, 6:39 pm - 🍀 ADARSH: Hello " fuck you " 😂
# I am again floating in air with some music & floaty imaginations
# 21/03/22, 6:39 pm - 🍀 ADARSH: ...
# 21/03/22, 6:40 pm - SURAJ 🍁: Ok
# 22/03/22, 7:16 am - 🍀 ADARSH: <Media omitted>
# 22/03/22, 7:16 am - SURAJ 🍁: 😅
# 22/03/22, 7:17 am - 🍀 ADARSH: I think I will rise it today a bit
# 22/03/22, 7:17 am - 🍀 ADARSH: What are u doing today !?
# 22/03/22, 7:17 am - SURAJ 🍁: not planned anything
# 22/03/22, 8:11 am - SURAJ 🍁: 😅
# 22/03/22, 11:34 am - 🍀 ADARSH: To be shameless , I digested well yesterday & pooped well today 💩
# 22/03/22, 11:34 am - 🍀 ADARSH: ...
# 22/03/22, 11:36 am - SURAJ 🍁: 🥳
# 24/03/22, 5:03 pm - 🍀 ADARSH: <Media omitted>
# 24/03/22, 5:03 pm - 🍀 ADARSH: I am admitting that I am a big idiot
#
# And u should help me with programming once we get together
# 24/03/22, 5:03 pm - 🍀 ADARSH: <Media omitted>
# 24/03/22, 5:32 pm - SURAJ 🍁: 😅
# 24/03/22, 6:46 pm - 🍀 ADARSH: If reply==😅
# Print('wtf does that mean')
# 25/03/22, 12:35 pm - 🍀 ADARSH: Dress !?
# 25/03/22, 12:36 pm - SURAJ 🍁: en aat?
# 25/03/22, 12:38 pm - 🍀 ADARSH: Ivatt kodtan en illa ava !?
# 25/03/22, 12:38 pm - SURAJ 🍁: nandra helteni
# 25/03/22, 12:38 pm - SURAJ 🍁: b*
# 25/03/22, 12:39 pm - 🍀 ADARSH: Ok alright
# 25/03/22, 6:22 pm - SURAJ 🍁: <Media omitted>
# 25/03/22, 8:50 pm - 🍀 ADARSH: Wooohhh !! Stud !!
# 25/03/22, 8:50 pm - SURAJ 🍁: 😅
# 25/03/22, 8:50 pm - 🍀 ADARSH: Did you like yours !?!?😁
# 25/03/22, 8:50 pm - SURAJ 🍁: 😂
# 25/03/22, 8:50 pm - SURAJ 🍁: yes
# 25/03/22, 8:50 pm - 🍀 ADARSH: 🤩
# 25/03/22, 8:51 pm - 🍀 ADARSH: Are my clothes fine too !?/😁😂
# 25/03/22, 8:51 pm - SURAJ 🍁: one of my dress is failed to ship,i want that one
# 25/03/22, 8:51 pm - SURAJ 🍁: awesome ,i want to keep yours also
# 25/03/22, 8:52 pm - 🍀 ADARSH: If its cash on del
# Order it once again then
# 25/03/22, 8:52 pm - 🍀 ADARSH: 😁🤣yeah yeah !! Whatever for u
# 25/03/22, 8:52 pm - SURAJ 🍁: they have no repaid money,so i will wait,i guess it will be delivered
# 25/03/22, 8:52 pm - 🍀 ADARSH: Ok alright then
# 25/03/22, 8:53 pm - 🍀 ADARSH: How much are missing
# 25/03/22, 8:53 pm - SURAJ 🍁: from now onwards we will talh english only,is it fine for you
# 25/03/22, 8:53 pm - SURAJ 🍁: only 1
# 25/03/22, 8:53 pm - 🍀 ADARSH: Yeah !! But if I am in village !! I think its not possible
# 25/03/22, 8:54 pm - 🍀 ADARSH: Else I am more excited than you
# 25/03/22, 8:54 pm - SURAJ 🍁: in clg and while texting
# 25/03/22, 8:54 pm - 🍀 ADARSH: Yessir !! We will
# 25/03/22, 8:54 pm - SURAJ 🍁: and are you told to do mini projects?
# 25/03/22, 8:55 pm - 🍀 ADARSH: Brother something inside me is saying
# We are about to face something huge shift in our lives and career and we should get ready to take massive amount of load and work
# If we do I bet we will soon be somewhere else
# 25/03/22, 8:56 pm - 🍀 ADARSH: And its definitely not easy
# 25/03/22, 8:57 pm - SURAJ 🍁: excited for it, feeling happy 😄
# 25/03/22, 8:57 pm - 🍀 ADARSH: No they didn't ,, but I am sure these motherfuckers surprisely come
#
# Hit very hard like never before
# 03/07/22, 5:32 am - 🍀 ADARSH: Urag idde , call recieve madak aglilla
# 03/07/22, 5:32 am - 🍀 ADARSH: What's the matter ??
# 03/07/22, 8:42 am - SURAJ 🍁: en illo bhai😂,hanga hacchinni
# 06/07/22, 12:51 pm - SURAJ 🍁: https://youtu.be/kICh_d6tHQk
#
# bhai his feelings 🙌🏻
# 06/07/22, 1:57 pm - 🍀 ADARSH: Wait
# 06/07/22, 4:41 pm - 🍀 ADARSH: Driven 💯✈️
# 07/07/22, 5:10 pm - 🍀 ADARSH: Hoyyiiieee
# 07/07/22, 5:26 pm - SURAJ 🍁: ha
# 07/07/22, 5:57 pm - SURAJ 🍁: alli room daag kle du library du book adav avn ond swalp safe id
# 07/07/22, 7:08 pm - 🍀 ADARSH: Ell adavoo
# 07/07/22, 7:08 pm - 🍀 ADARSH: Ir  ig nalind tough aiti avg madod , amel nodten bhai
# 07/07/22, 7:39 pm - SURAJ 🍁: yavagare nod,ott elli kaldu andra atta,adka helini
# 07/07/22, 7:40 pm - SURAJ 🍁: https://music.youtube.com/watch?v=c4KCPpVWx0E&feature=share
# 07/07/22, 8:33 pm - 🍀 ADARSH: Alright
# 08/07/22, 5:54 pm - 🍀 ADARSH: https://youtu.be/v9BclXHp9XI
#
# A Bible video 💯
# 08/07/22, 5:54 pm - 🍀 ADARSH: Watch full
# 08/07/22, 7:41 pm - SURAJ 🍁: afterwards,i slept till now ,have to study 2 subs
# 10/07/22, 2:45 pm - 🍀 ADARSH: Bhai rutuja yando jote full hachkond Nadu kunt triple ride hodlo
# 10/07/22, 3:03 pm - SURAJ 🍁: aki tull hada😂 auti sullimagl hatr bido akinna😂😂 innond swalp divsdaag manyag gottakketi madvi maadi kalastar akin chappal le badad😂😂
# 10/07/22, 3:03 pm - SURAJ 🍁: aunty*
# 10/07/22, 5:07 pm - 🍀 ADARSH: Yupp broo
# 17/07/22, 6:58 pm - 🍀 ADARSH: <Media omitted>
# 17/07/22, 6:59 pm - SURAJ 🍁: hairstyle maadteni gapp ivn gate
# 17/07/22, 6:59 pm - 🍀 ADARSH: Alright 👍
# 17/07/22, 7:02 pm - 🍀 ADARSH: <Media omitted>
# 17/07/22, 7:03 pm - SURAJ 🍁: ellindra hudkyadatiro
# 17/07/22, 7:04 pm - 🍀 ADARSH: Av obb iddo same nin gate na 😂🤣 insta olag
# 17/07/22, 7:07 pm - SURAJ 🍁: 😂 bhai avr chand adaro na illo😂😂
# 17/07/22, 8:29 pm - 🍀 ADARSH: Fuuuk you
# 20/07/22, 6:04 pm - SURAJ 🍁: bhai tcs interview yavag togotar?m
# 21/07/22, 10:28 am - SURAJ 🍁: area mydata, data, readwrite ; allocates area in RAM with name mydata
# number DCD 0
# ; allocates 4 bytes in RAM with label number.
# area mycode, code, readonly ; allocates area in ROM with name mycode
# export __main
# ; label __main is exported so that
# ;startup_lpc17xx.s can access it.
# __main ENTRY
# ; entry point into the assembly code
# MOV R0, #0x00
# ; counter for number of Zeros
# MOV R1, #0x00
# ; counter for number of ones
# MOV R2, #32
# ; counter for number of rotations
# LDR R3, =number
# ; copy address of label number into register R3
# LDR R4, [R3]
# ; copy content pointed by R3 into register R4
# again
# RORS R4, #1
# ; rotate the content of R4 to right by one bit, carry
# ;flag is updated.
# BCC label0
# ; branch to label0 if the carry is reset/cleared
# ADD R1,#0x01
# ; increment the counter for number of ones
# B label2
# ; branch to label2
# label0
# ADD R0,#0x01
# ; increment the counter for number of zeros
# label2
# SUBS R2,#0x01
# ; decrement the counter for number of rotations
# BNE again
# ; goto next rotation if the value of R2 is not zero
# END
# 21/07/22, 10:59 am - SURAJ 🍁: <Media omitted>
# 21/07/22, 11:04 am - 🍀 ADARSH: What is this bro !? 😅
# 21/07/22, 11:05 am - SURAJ 🍁: bhai pc ga kalsak kalsinyo,😂 nan mute maado whatsappdaga
# 21/07/22, 4:21 pm - 🍀 ADARSH: Yeah whatever, i use whatsapp rarely as there is nothing to do with it...you can carry on
# 21/07/22, 8:19 pm - SURAJ 🍁: bhai busy adi en?
# 21/07/22, 8:21 pm - SURAJ 🍁: bencho
# 21/07/22, 9:46 pm - 🍀 ADARSH: Bhai illoo
# 21/07/22, 9:47 pm - 🍀 ADARSH: Nali na aiti namd final phase
# Nang gott irakkilla avnvn
# 21/07/22, 9:47 pm - 🍀 ADARSH: Matt beligge jaldi barbek adk
# 21/07/22, 9:47 pm - 🍀 ADARSH: ..
# 21/07/22, 10:18 pm - SURAJ 🍁: kett teli hadtaro clg dora,nale phase mugisko chandhang ameli matadonu togo
# gn
# 21/07/22, 10:19 pm - 🍀 ADARSH: Yeah bro !! For sure 💯
# 22/07/22, 11:31 am - SURAJ 🍁: bro can you just tell me OTP ,i forgot my password so for recovery i put your gmail as secondary gmail,you wil receive one OTP ,send me that OTP please
# 22/07/22, 11:51 am - 🍀 ADARSH: <Media omitted>
# 22/07/22, 6:53 pm - 🍀 ADARSH: https://youtu.be/vTnwD5wtCb0
# 23/07/22, 9:14 am - SURAJ 🍁: <Media omitted>
# 23/07/22, 9:14 am - SURAJ 🍁: <Media omitted>
# 23/07/22, 9:14 am - SURAJ 🍁: <Media omitted>
# 23/07/22, 9:14 am - SURAJ 🍁: congratulations bro🥳🥳🥳🔥5000 dollars
# 23/07/22, 9:15 am - 🍀 ADARSH: Yeah i seen by all the friends messages, that guy's dumb idiotic scams ..
# 23/07/22, 9:17 am - SURAJ 🍁: https://www.amishrakefight.org/gfy/
#
# i will send him this link
# 23/07/22, 9:18 am - 🍀 ADARSH: Sure 💯
# 23/07/22, 12:44 pm - SURAJ 🍁: <Media omitted>
# 23/07/22, 1:23 pm - 🍀 ADARSH: Well done mannn... Keep watching over him 😄
# 23/07/22, 1:23 pm - 🍀 ADARSH: En madati
# 23/07/22, 1:24 pm - SURAJ 🍁: uta
# 23/07/22, 1:24 pm - 🍀 ADARSH: Ig madini
# 23/07/22, 1:24 pm - 🍀 ADARSH: Bhai ninne Alli ad hanagi iddu
# 23/07/22, 1:24 pm - 🍀 ADARSH: Adk call madatini na
# 23/07/22, 1:24 pm - SURAJ 🍁: oh
# 17/09/22, 2:38 pm - 🍀 ADARSH: Ok ok thanks ...I will
# 23/09/22, 4:21 pm - 🍀 ADARSH: B
#
#
#
#
#
#
#
#
# Sdk ...
# 23/09/22, 5:31 pm - SURAJ 🍁: hello😁
# 23/09/22, 6:23 pm - 🍀 ADARSH: How was interview !?/ & when was it actually 😆
# 23/09/22, 6:48 pm - SURAJ 🍁: time hasn't come yet, i forgot everything which i read
# 23/09/22, 6:57 pm - 🍀 ADARSH: How is development!?
# 23/09/22, 6:57 pm - 🍀 ADARSH: Fuck that , how are you btw !?
# 23/09/22, 6:57 pm - 🍀 ADARSH: ..
# 23/09/22, 7:10 pm - SURAJ 🍁: from when you are coming to college?
# 23/09/22, 7:11 pm - SURAJ 🍁: slowly slowly getting better in it
# 23/09/22, 8:52 pm - 🍀 ADARSH: Ok its been a long time , let me tell you even if it bores you or whatever....
#
#
# I wasn't serious at dsa before
# But since past week or 10 days , i m slowly putting in the effort or at least understanding & watching videos well
#
# I might be a lot behind you, I agree , but I hope I will catch up with u in a few months...
#
# I am not into dev yet as my as a few things need to be fixed
#
#
# Thanks for guiding me through !! I got into the path well
#
#
# Getting rejected by 5 companies sucks , but standing & preparing for big fights always rocks
#
# As I don't have pass & don't have money too 😆 , I guess I will appear after dasara
#
# But I will come one day to make admission , I will inform you
#
# & thanks for everything my bro 🙏🤍..!!
# 23/09/22, 8:52 pm - 🍀 ADARSH: ..
# 23/09/22, 11:43 pm - SURAJ 🍁: 🥳🥳🥳🥳🥳🥳bhai lets continue this till we get into company,lets c who the mother fucker has dare to stop us
# 24/09/22, 6:12 am - 🍀 ADARSH: Indeed !! I'm with u ⚡
# 26/09/22, 2:28 pm - 🍀 ADARSH: For the first time in my life I wrote a logic for a easiest problem which works
#
# But due to syntax somehow messed it up 😁 just happy for trying 1st time...
# 26/09/22, 2:28 pm - 🍀 ADARSH: & btw where to slove problems in leetcode !?
# 26/09/22, 2:28 pm - 🍀 ADARSH: This also in leetcode
# 26/09/22, 3:01 pm - SURAJ 🍁: search for problem name and type leetcode in google,you will get
# firstly solve easy ones
# 26/09/22, 3:02 pm - SURAJ 🍁: you will not get all the problems of sumit malik there
# 26/09/22, 3:02 pm - SURAJ 🍁: only most important problems will be there on leetcode
# 26/09/22, 3:18 pm - 🍀 ADARSH: Ok bro , I will
# 26/09/22, 3:19 pm - 🍀 ADARSH: My laptop's sound has gone for some reason , I tried everything
#
# But I am doing my things except video and audio
# 27/09/22, 7:42 pm - 🍀 ADARSH: Hii suryaoo....
# Bhai nanu front end start madbek madeni
# Angela course heng purchase madod en !!?
#
# En pepcoding web dev !?
# Codewithharry !?
# Apna clg !?
#
# Reply as quick as possible pls... I need guidance ...I hope you help 🙏
# 27/09/22, 7:42 pm - SURAJ 🍁: maadbyad
# 27/09/22, 7:42 pm - 🍀 ADARSH: Matt !?
# 27/09/22, 7:44 pm - SURAJ 🍁: youtube ,watch whichever you feel easy,html is easy
# first complete that one
# 27/09/22, 7:44 pm - 🍀 ADARSH: Ok sure
# 27/09/22, 7:44 pm - SURAJ 🍁: apna clg,code with harry and pepcoding all are good
# 27/09/22, 7:45 pm - 🍀 ADARSH: Ok alright , I will start right now
# Thanks...🙌🏻
# 02/10/22, 7:32 am - SURAJ 🍁: <Media omitted>
# 02/10/22, 7:37 am - 🍀 ADARSH: 🙌🏻🤍🔥🔥🔥🔥
# 02/10/22, 7:37 am - SURAJ 🍁: heng marks hakidar eno ro😂🙌🏻🙌🏻🙌🏻
# 02/10/22, 7:38 am - 🍀 ADARSH: Bhai awesome
# 03/10/22, 9:01 pm - 🍀 ADARSH: Sry wasn't able to pick call
# Tell me about it
# 06/10/22, 8:49 pm - SURAJ 🍁: <Media omitted>
# 09/10/22, 5:04 pm - SURAJ 🍁: class Solution {
# 	public String minWindow(String s, String t) {
# 		// shortifying
# 		int slen = s.length();
# 		int tlen = t.length();
#
# 		// preparing t string frequency map
# 		HashMap<Character, Integer> tfmap = new HashMap<>();
# 		for (int i = 0; i < t.length(); i++) {
# 			char x = t.charAt(i);
# 			tfmap.put(x, tfmap.getOrDefault(x, 0) + 1);
# 		}
#
# 		// iterating through s string
# 		int i = 0, j = 0;
#
# 		// map for s string character frequencies
# 		HashMap<Character, Integer> sfmap = new HashMap<>();
#
# 		int match_count = 0;
# 		String min_substring = "";
# 		int min_ss_len = Integer.MAX_VALUE;
# 		while (i < slen) {
# 			// putting ith element to sfmap
# 			char x = s.charAt(i);
#
# 			// checking whether its in t string
# 			if (tfmap.containsKey(x) == true) {
# 				sfmap.put(x, sfmap.getOrDefault(x, 0) + 1);
#
# 				// checking whether it was usefull put
# 				int xcount = sfmap.get(x);
# 				int pcount = tfmap.get(x);
# 				if (xcount <= pcount) {
# 					match_count = match_count + 1;
# 				} else {
#
# 				}
#
# 				// checking whether all characters of t are in s
# 				if (match_count == tlen) {
# 					// taking that substring out
# 					String sub_string = s.substring(j, i + 1);
# 					int sslen = sub_string.length();
#
# 					// checking whether its minimum length substring
# 					if (sslen < min_ss_len) {
# 						System.out.println(sub_string + " 1");
# 						min_substring = sub_string;
# 						min_ss_len = sslen;
# 					} else {
#
# 					}
#
# 					// moving j forward
# 					while (j <= i) {
# 						// removing/reducing jth element from sfmap
#
# 						char c = s.charAt(j);
# 						if (sfmap.containsKey(c) == true) {
# 							int ccount = sfmap.get(c);
#
# 							// if its 1 then remove else reduce
# 							if (ccount == 1) {
# 								sfmap.remove(c);
# 							} else {
# 								sfmap.put(c, sfmap.get(c) - 1);
# 							}
# 							j++;
# 							// checking still the substring is valid one
# 							if (sfmap.containsKey(c) == false) {
# 								match_count = match_count - 1;
# 								break;
# 							} else {
# 								// p - preffered
# 								int new_c_count = sfmap.get(c);
# 								int p_count = tfmap.get(c);
# 								if (new_c_count >= p_count) {
# 									// taking that substring out
# 									String sub_string2 = s.substring(j, i + 1);
# 									int sslen2 = sub_string2.length();
#
# 									// checking whether its minimum length substring
# 									if (sslen2 < min_ss_len) {
# 										System.out.println(sub_string2 + " 2");
# 										min_substring = sub_string2;
# 										min_ss_len = sslen2;
# 									} else {
#
# 									}
#
# 								} else {
# 									match_count = match_count - 1;
# 									break;
# 								}
# 							}
# 						} else {
# 							j++;
# 							// taking that substring out
# 							String sub_string3 = s.substring(j, i + 1);
# 							int sslen3 = sub_string3.length();
#
# 							// checking whether its minimum length substring
# 							if (sslen3 < min_ss_len) {
# 								System.out.println(sub_string3+ " 3");
# 								min_substring = sub_string3;
# 								min_ss_len = sslen3;
# 							} else {
#
# 							}
#
# 						}
# 					}
# 				} else {
#
# 				}
# 				i = i + 1;
# 			} else {
# 				i = i + 1;
# 			}
# 		}
#
# 		if(min_ss_len == Integer.MAX_VALUE){
# 			return "";
# 		} else {
# 			return min_substring;
# 		}
# 	}
# }
# ...
# you will become smart and most intelligent person, you will becomes stringer than ever, you will enjoy like nobody does, there will be no situation which can fear you, everybody will start to understand you and i m sensing that..that day is nearer,
#
# what i think is...once you taste the success..then there is nobody who can stop you...you need nobodies advice ..on your own you will rise like nobody..
#
#
#
# in that all.....
# what i am doing is just taking the characters which i can adopt from you... understanding them only takes 5-6 months..but i love them.
# btw you are the first person i didn't compete with and admired.
# 09/01/23, 2:15 pm - 🍀 ADARSH: Lol ! Again I have no words
# But i don't want to explain your understanding and friendship by fancy words & your contribution to my life
#
# You have grown such a fine man in the past months ! Can't measure it with anything
#
# Love to give back someday what you have given to me
# ( although its impossible )
#
# Lol ! Screw it ,,, lets study
# Don't text back for a while
# 😂
#
# Man.. I am awesomest  , just to have friends who are family  👪 I can die peacefully 💯
# 10/01/23, 9:51 am - SURAJ 🍁: Infosys Off Campus Drive 2023 for Freshers | 2020/2021/2022 Batch | Across India | Last Date : 13th January 2023
#
# Job Role : Specialist Programmer
# Qualification : BE/BTech/ME/MTech/MCA/MSc
# Batch : 2020/2021/2022 Batch
# Salary : INR 9.5 LPA
# Job Location : Across India
# Venue Location : Virtual(Online)
# Last Date : 13th January 2023
#
# To Apply:
# https://bit.ly/Infosys-Recruitment-Program
# If it is not useful to you...
# Share this in your circle, this create someone's career
# 10/01/23, 9:52 am - 🍀 ADARSH: Its only uptill 22 batch broo
# 10/01/23, 9:53 am - 🍀 ADARSH: Sure I will
# 10/01/23, 9:53 am - SURAJ 🍁: oh shit
# 10/01/23, 9:54 am - 🍀 ADARSH: What shit
# 10/01/23, 9:54 am - SURAJ 🍁: its not for 23 batch
# 10/01/23, 9:55 am - 🍀 ADARSH: Exactly what I said 😁
# 10/01/23, 9:55 am - 🍀 ADARSH: ..
# 10/01/23, 9:55 am - SURAJ 🍁: ya
# 10/01/23, 1:39 pm - 🍀 ADARSH: https://youtu.be/6Y-V_8UJ_xU
# 10/01/23, 2:04 pm - SURAJ 🍁: https://youtu.be/nCD2hj6zJEc
# 10/01/23, 2:12 pm - SURAJ 🍁: https://youtu.be/DAYszemgPxc
# 10/01/23, 2:50 pm - 🍀 ADARSH: The video's first comment satisfied me for a while 🪶
# 10/01/23, 10:20 pm - SURAJ 🍁: music is so awesome, addicted to it
# 10/01/23, 10:30 pm - SURAJ 🍁: ...
# 20/01/23, 12:25 am - SURAJ 🍁: https://youtu.be/tXDzgaPoJQI
# 21/01/23, 11:30 am - 🍀 ADARSH: 🌞
# 21/01/23, 1:04 pm - SURAJ 🍁: <Media omitted>
# 21/01/23, 2:32 pm - 🍀 ADARSH: Me telling you is like a student guiding his guide
#
# Anyway if I have to try to explain , i definitely will
# 21/01/23, 2:38 pm - 🍀 ADARSH: And about that phone call , I was not wanting to talk about that but here anyway
#
# You are sometimes really a lifesaver for me , you can see my blindspot , initially while on the call my ego tried to block your words of truth
#
# Then later when i see , those were simple truths that I failed to realize & just like that I was off the path long ago
# ..the truth bombs were needed & you supplied them at the right time
#
# I was soo sunk in myself that I can't even see myself....you have my gratitude
#
#
# & about meditation
# Day 1.I did it for a fewer minutes , no change
# Day 2. I am getting to get familiar & understand why I am slowly get off the path later
#
# & rest I will be exploring soon
# 21/01/23, 2:39 pm - 🍀 ADARSH: ..
# 21/01/23, 5:38 pm - SURAJ 🍁: before anything else....
# while meditating....
#  sit straight and there is one tying i have found dont know how to tell it in chat ,i will explain u on next meet.
#
#  chant for your god (for beginners i think its best to chant for not devine gods but admiring great bhakta*s i chant for "Basavanna" he is my idol and sign for devine purity and unlimited energy source for expectation-less hard work)
#
# while chanting calm your mind ,observe your actions and thoughts were they are going... focus on chant count try to not to think any thing else...(try to not to forget the count throughout the meditation) keep chanting as slow as possible
#
# it will calm you to another level ,you will smile like you never did till today..
#
# may god bring light in our life and also in life of all good hard workers 🙏🏻 may this goodness never vanish 🌸
# 21/01/23, 6:23 pm - 🍀 ADARSH: Thank you 🌿
# 25/01/23, 11:29 am - SURAJ 🍁: https://www.clearias.com/memory-techniques/
# 25/01/23, 11:47 pm - SURAJ 🍁: <Media omitted>
# 28/01/23, 10:42 am - SURAJ 🍁: <Media omitted>
# 28/01/23, 7:59 pm - SURAJ 🍁: durga software channel videos,very much knowledgeable
# sir is awesome,see once when u r free
# 28/01/23, 9:34 pm - SURAJ 🍁: to learn java its good
# 29/01/23, 10:46 am - 🍀 ADARSH: sure , I will check it out
# 30/01/23, 8:30 pm - SURAJ 🍁: Dear Students,
# This is to notify that our placement team is planning for few placement drives exclusively for unplaced students probably in the month of March.
# And for these drives probably in the last week of February we are planning to have placement training from Company Expertees.
#
# We request you to fill this 👇🏻 form so that we can get the exact count of students who wish to surely appear for these drive.
#
#  *PLACED STUDENTS ARE NOT ALLOWED*
#
# https://forms.gle/3Mp9FdHLXEePCNDp7
# 30/01/23, 8:30 pm - SURAJ 🍁: Do the needful till 1st February.
# 30/01/23, 8:31 pm - SURAJ 🍁: nim sir kalsidar en nodri nim branch ga
# 30/01/23, 9:28 pm - 🍀 ADARSH: Kalsilla avr
# 30/01/23, 9:32 pm - 🍀 ADARSH: Thanks for this
# 31/01/23, 6:41 pm - SURAJ 🍁: <Media omitted>
# 31/01/23, 6:41 pm - SURAJ 🍁: <Media omitted>
# 31/01/23, 6:41 pm - SURAJ 🍁: today is last date
# 31/01/23, 7:19 pm - 🍀 ADARSH: Ok
# 31/01/23, 7:20 pm - 🍀 ADARSH: Thank you
#
# I will apply as soon as I reach home
# 31/01/23, 10:40 pm - SURAJ 🍁: Man bday completed in McDonald's
# 01/02/23, 10:42 am - 🍀 ADARSH: How was it !?
# 01/02/23, 10:54 am - SURAJ 🍁: rich wibe nothing else😅
# 02/02/23, 6:22 am - 🍀 ADARSH: Hey bro can you tell me about passport
# 02/02/23, 12:07 pm - SURAJ 🍁: yes,call me at the time of applying
# 02/02/23, 3:26 pm - 🍀 ADARSH: sure !!!
# 02/02/23, 7:57 pm - 🍀 ADARSH: https://youtu.be/qPDbNYcCXi8
# 03/02/23, 7:30 am - SURAJ 🍁: <Media omitted>
# 03/02/23, 7:35 am - SURAJ 🍁: <Media omitted>
# 03/02/23, 8:57 am - 🍀 ADARSH: Facts !
# Can I assume these are from chanakya ! ?
# 03/02/23, 9:09 am - SURAJ 🍁: yes chanakya the legend
# 04/02/23, 11:54 am - 🍀 ADARSH: Hey brother .. I will call you evening
# 04/02/23, 4:35 pm - 🍀 ADARSH: <Media omitted>
# 07/02/23, 1:58 pm - SURAJ 🍁: <Media omitted>
# 07/02/23, 2:11 pm - SURAJ 🍁: <Media omitted>
# 07/02/23, 3:04 pm - SURAJ 🍁: <Media omitted>
# 07/02/23, 3:22 pm - 🍀 ADARSH: According to chanakya
#
# He compares a person who don't have a guru & self taught , to a woman who had baby without her husband
#
# Because that knowledge can be misleading & if anyone asks both the person & a woman , who caused this they can't answer
#
# (may be I am 100% wrong )
# 07/02/23, 3:24 pm - 🍀 ADARSH: The low level people want money
#
# Middle level want money & a little reputation& respect (honour)
#
# Nobles (those who are respected in society ) only cares about their integrity & respect (honour)
# 07/02/23, 3:25 pm - 🍀 ADARSH: One should either enjoy or hardwork ( do one thing )
#
# Which means one should not ruin enjoyment if they don't want to work further
#
# If one wants to work hard & move up , they must focus on that & should not care about enjoyment
# 07/02/23, 3:25 pm - 🍀 ADARSH: ( I may be 100% absolutely wrong )
# 07/02/23, 3:54 pm - SURAJ 🍁: ok thanks 👍🏻
# 07/02/23, 11:15 pm - SURAJ 🍁: <Media omitted>
# 08/02/23, 7:03 am - 🍀 ADARSH: 😁🙏🏼 jai
# 08/02/23, 2:51 pm - 🍀 ADARSH: I don't know what endorse is actually
#
# But you did & i thought its a good thing , & I did the same XD
# 08/02/23, 3:05 pm - SURAJ 🍁: https://www.overleaf.com/project/63e36caf231234689069fcc2
# 08/02/23, 3:19 pm - SURAJ 🍁: this is better
#
# https://www.overleaf.com/latex/templates/deedy-cv/bjryvfsjdyxz
# 08/02/23, 4:14 pm - 🍀 ADARSH: Thank you 🙌🏻🤍
# 08/02/23, 7:59 pm - SURAJ 🍁: NEW...AI APPS ARE AMAGING 🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 08/02/23, 8:23 pm - 🍀 ADARSH: Yesss
# 08/02/23, 8:24 pm - 🍀 ADARSH: Uta madatidde adk call recieve madlilla , I have to go tomorrow for internship to clg
#
# So I hope we can speak later
# 09/02/23, 11:07 am - SURAJ 🍁: came to know that my brother is earning 15lack monthly,
# what I earn in 30 days...my brother earns in 1 day, inspired bu his success and aim and mindset 💪 hoping that we both also achive way more than these all
# 09/02/23, 11:09 am - SURAJ 🍁: "Never settle Never bound"  lets embrace the journey with all we can give 🗽
# 09/02/23, 1:26 pm - 🍀 ADARSH: Really amazed tp hear someone in your family circle do that
# Lets enjoy and respect the process ...🙌🏻
# 09/02/23, 10:24 pm - SURAJ 🍁: <Media omitted>
# 09/02/23, 10:25 pm - SURAJ 🍁: was planning for MS in grmany/ Japan, but my father is advising me to take 4-5 years experience in tata
# 09/02/23, 11:15 pm - SURAJ 🍁: <Media omitted>
# 10/02/23, 5:57 am - 🍀 ADARSH: Yeah this I got it
# 10/02/23, 5:57 am - 🍀 ADARSH: But this i didn't get very well
# 10/02/23, 11:54 am - SURAJ 🍁: what tell..
# 10/02/23, 11:55 am - SURAJ 🍁: important exams and opportunities after BE
# 10/02/23, 11:57 am - 🍀 ADARSH: Ohh alright
# 10/02/23, 12:00 pm - 🍀 ADARSH: According to my inosuke head , you solved the problem in just 135 ms which beats almost 99% of other submissions
# 10/02/23, 12:03 pm - SURAJ 🍁: 🥳as I expected,You are wrong
#
# the amazing thing was,
# there are same percentage of people in every milisecond solutions,
# means
# 1.59% people have solved it in 325ms
# 1.59% people have solved it in 311ms
# 1.59% people have solved it in 408ms
# 1.59% people have solved it in 130ms
# ..
# ..
# so on
# 10/02/23, 12:04 pm - 🍀 ADARSH: Ahhhhh ....as always 🙌🏻
# 10/02/23, 12:10 pm - SURAJ 🍁: not always..,some times
# 10/02/23, 12:48 pm - 🍀 ADARSH: <Media omitted>
# 10/02/23, 12:50 pm - SURAJ 🍁: 🔥💪🥳 i think you are in love with linked lists
# 10/02/23, 12:50 pm - 🍀 ADARSH: Nah its just striver's sheet
# & binary trees need recursion which I am still learning , that's why
# 10/02/23, 12:51 pm - SURAJ 🍁: 🐧 i will also do more probs from today
# 10/02/23, 4:43 pm - 🍀 ADARSH: <Media omitted>
# 10/02/23, 4:54 pm - 🍀 ADARSH: <Media omitted>
# 10/02/23, 4:59 pm - SURAJ 🍁: <Media omitted>
# 10/02/23, 7:32 pm - SURAJ 🍁: cgpa 7.5 haaki la
# 10/02/23, 7:49 pm - 🍀 ADARSH: Hu bhai select ago mata re
# 11/02/23, 9:22 am - SURAJ 🍁: <Media omitted>
# 11/02/23, 9:29 am - 🍀 ADARSH: Agreed !
# 11/02/23, 9:29 am - SURAJ 🍁: how to use chatgpt
# 11/02/23, 9:29 am - SURAJ 🍁: i am not able to signup
# 11/02/23, 9:31 am - 🍀 ADARSH: I never used it
# I am going to that mech internship today
# 11/02/23, 9:32 am - SURAJ 🍁: and yesterday i did my project but failed to deploy it as its asking for credit card😅
# 11/02/23, 9:32 am - SURAJ 🍁: 😅 okay
# 11/02/23, 11:22 am - SURAJ 🍁: <Media omitted>
# 12/02/23, 10:41 am - SURAJ 🍁: Just have a glance over bosscoder academy and masters union , what do you think about them?
# 12/02/23, 12:11 pm - 🍀 ADARSH: Results are out , cleared but thses mfs reduced my marks too much bro , system sucks
# 12/02/23, 12:24 pm - SURAJ 🍁: man congrats 😀😀 very happy for you
# 12/02/23, 12:48 pm - 🍀 ADARSH: https://results.vtu.ac.in/JFEcbcs23/index.php
# 12/02/23, 12:49 pm - SURAJ 🍁: <Media omitted>
# 12/02/23, 12:50 pm - 🍀 ADARSH: <Media omitted>
# 12/02/23, 5:23 pm - SURAJ 🍁: man i calculated sgpa in takeiteasy.com
# its showing 8.909
#
# Thanks man your technique helped me lot👍🏻🤠
# 12/02/23, 6:18 pm - SURAJ 🍁: <Media omitted>
# 12/02/23, 6:55 pm - 🍀 ADARSH: bro don't calculate percentage using that , that calculates wrong
# 12/02/23, 6:55 pm - SURAJ 🍁: whooooo😂 i also thaught,how i can get that much
# 12/02/23, 6:56 pm - 🍀 ADARSH: they are the definition of many people's dreams
# 12/02/23, 6:56 pm - SURAJ 🍁: not getting sleep😅
# 12/02/23, 6:57 pm - 🍀 ADARSH: wanted to tell you something that resume scanners and all are sometimes useless unless you are applying for pbc's                             because my resume scored 47 points , and that chandru's resume scored 4  …..  and you know who got the call and the offer
# 12/02/23, 6:58 pm - 🍀 ADARSH: reality is quite different actually , not that I am frustrated or anything like that , but facts are facts lol
# 12/02/23, 6:58 pm - SURAJ 🍁: 😅🙌🏻 have no clue how this happened
# 12/02/23, 6:59 pm - SURAJ 🍁: then what is it actually?
# 12/02/23, 6:59 pm - SURAJ 🍁: man i have found 1 glitch
# 12/02/23, 7:00 pm - 🍀 ADARSH: for me its just the line from sri krishna , do your work without ever expecting the results , rest will follow or not
# 14/02/23, 9:16 am - SURAJ 🍁: <Media omitted>
# 14/02/23, 9:23 am - 🍀 ADARSH: I m really sorry to say that I cannot understand it either
# 16/02/23, 12:08 pm - SURAJ 🍁: <Media omitted>
# 16/02/23, 12:09 pm - SURAJ 🍁: <Media omitted>
# 16/02/23, 12:09 pm - SURAJ 🍁: Rank 3 in my division 🥳
# 16/02/23, 12:10 pm - 🍀 ADARSH: You are 🔥
# 16/02/23, 12:10 pm - SURAJ 🍁: thank you 🙏🙂
# 16/02/23, 12:11 pm - 🍀 ADARSH: How did you hosted it 😁
# 16/02/23, 12:11 pm - SURAJ 🍁: i failed to host it
# 16/02/23, 12:11 pm - SURAJ 🍁: i have just sent you the html file, add some css to it
# 16/02/23, 12:11 pm - 🍀 ADARSH: I am outside in a temple
# 16/02/23, 12:12 pm - 🍀 ADARSH: I will do it by evening
# 16/02/23, 12:12 pm - SURAJ 🍁: take 10 days , add anytime
# 16/02/23, 12:12 pm - 🍀 ADARSH: Sure I will

# %%
pattern = '\d{1,2}\/\d{2,4}\/\d{2,4},\s\d{1,2}:\d{1,2}\s\w{1,2}\s-\s'

# %%
messeges = re.split(pattern, data)[1:]
for messege in messeges:
    print(messege)
# Out:
# Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Still some are there but they are not under offer
#
# SURAJ 🍁: wiat
#
# SURAJ 🍁: wait
#
# 🍀 ADARSH: The brand I ordered was priced high & under no offer
#
# 🍀 ADARSH: Black shirts are aren't under offer
#
# SURAJ 🍁: tattoo on his hand are killer 😅
#
# 🍀 ADARSH: Yeah yeah !!
#
# SURAJ 🍁: https://www.ajio.com/netplay-checked-shirt-with-patch-pocket/p/441123883_white
#
# SURAJ 🍁: https://www.ajio.com/netplay-checked-shirt-with-patch-pocket/p/441123884_navy
#
# 🍀 ADARSH: Wich one do you want 😂😂
#
# 🍀 ADARSH: Or both !?
#
# SURAJ 🍁: both👍🏻
#
# 🍀 ADARSH: Alright let me check for a min
#
# SURAJ 🍁: approx 300 each they are
#
# 🍀 ADARSH: Yes yes !!
#
# 🍀 ADARSH: What about size btw
#
# SURAJ 🍁: i will check n send you wait
#
# 🍀 ADARSH: Alright
#
# SURAJ 🍁: offer is till what time
#
# 🍀 ADARSH: Today evening or night maxx
#
# SURAJ 🍁: asap i will send
#
# 🍀 ADARSH: Alright
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: horag adeni ,gapp
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: https://www.ajio.com/netplay-checked-shirt-with-patch-pocket/p/441119265_white
#
# SURAJ 🍁: https://www.ajio.com/netplay-checked-cotton-shirt-with-patch-pocket/p/441123873_white
#
# SURAJ 🍁: https://www.ajio.com/netplay-checked-cotton-shirt/p/441114059_mediumblue
#
# SURAJ 🍁: https://www.ajio.com/netplay-checked-cotton-shirt/p/441114059_copper
#
# SURAJ 🍁: 1
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: https://www.ajio.com/netplay-striped-shirt-with-patch-pocket/p/441123936_rust
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: I recently tried CashKaro.com & highly recommend it! You get extra Cashback on top of all retailer discounts.
#  Try it out: https://cashk.app.link/lao8Cfn4xob
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: Limited-time deal: Fur Jaden Navy Casual Backpack with USB Charging Port and 15.6 Inch Laptop Pocket https://www.amazon.in/dp/B07G4G3NPD/ref=cm_sw_r_apan_glt_i_dl_MYT1JFKWSFGKT6FJAFNB?_encoding=UTF8&psc=1
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: listy=["red","green","blue".....]
# my_colour = listy[int(random(10))]
# k = 1
# while(k)
#     k = True
#     my_colour = listy[int(random(10))]
#     user_color = str(input("guess a color : "))
#     if(user_color == my_colour)
#         print("yahoo same colour")
#     elif(user_color == "no")
#         k = False
#     else
#         print("nadi manig not same color")
#
# 🍀 ADARSH: print('you are a holy stud')
#
# SURAJ 🍁: while(True)
#    print (" you are also ")
#
# 🍀 ADARSH: Yeah yeah !! Whatever 😂😂
#
# SURAJ 🍁: 😁
#
# 🍀 ADARSH: Bankacnum=int(input("enter the number linked with phonepe or whatever kind of pay ")
#
# 🍀 ADARSH: Imma launch some money
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: use long long int
#
# 🍀 ADARSH: Eee hatroo
#
# 🍀 ADARSH: Python
#
# SURAJ 🍁: 😅
#
# 🍀 ADARSH: Number hel ig 😂😂
#
# 🍀 ADARSH: For this reason
#
# SURAJ 🍁: 8197344704
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: 👍🏻
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: I chewed the veggies & food slowly & completely and it took about entire 1 hr
#
# SURAJ 🍁: 😅 any benifits you seen?
#
# 🍀 ADARSH: Hello " fuck you " 😂
# I am again floating in air with some music & floaty imaginations
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: Ok
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: 😅
#
# 🍀 ADARSH: I think I will rise it today a bit
#
# 🍀 ADARSH: What are u doing today !?
#
# SURAJ 🍁: not planned anything
#
# SURAJ 🍁: 😅
#
# 🍀 ADARSH: To be shameless , I digested well yesterday & pooped well today 💩
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: 🥳
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: I am admitting that I am a big idiot
#
# And u should help me with programming once we get together
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: 😅
#
# 🍀 ADARSH: If reply==😅
# Print('wtf does that mean')
#
# 🍀 ADARSH: Dress !?
#
# SURAJ 🍁: en aat?
#
# 🍀 ADARSH: Ivatt kodtan en illa ava !?
#
# SURAJ 🍁: nandra helteni
#
# SURAJ 🍁: b*
#
# 🍀 ADARSH: Ok alright
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Wooohhh !! Stud !!
#
# SURAJ 🍁: 😅
#
# 🍀 ADARSH: Did you like yours !?!?😁
#
# SURAJ 🍁: 😂
#
# SURAJ 🍁: yes
#
# 🍀 ADARSH: 🤩
#
# 🍀 ADARSH: Are my clothes fine too !?/😁😂
#
# SURAJ 🍁: one of my dress is failed to ship,i want that one
#
# SURAJ 🍁: awesome ,i want to keep yours also
#
# 🍀 ADARSH: If its cash on del
# Order it once again then
#
# 🍀 ADARSH: 😁🤣yeah yeah !! Whatever for u
#
# SURAJ 🍁: they have no repaid money,so i will wait,i guess it will be delivered
#
# 🍀 ADARSH: Ok alright then
#
# 🍀 ADARSH: How much are missing
#
# SURAJ 🍁: from now onwards we will talh english only,is it fine for you
#
# SURAJ 🍁: only 1
#
# 🍀 ADARSH: Yeah !! But if I am in village !! I think its not possible
#
# 🍀 ADARSH: Else I am more excited than you
#
# SURAJ 🍁: in clg and while texting
#
# 🍀 ADARSH: Yessir !! We will
#
# SURAJ 🍁: and are you told to do mini projects?
#
# 🍀 ADARSH: Brother something inside me is saying
# We are about to face something huge shift in our lives and career and we should get ready to take massive amount of load and work
# If we do I bet we will soon be somewhere else
#
# 🍀 ADARSH: And its definitely not easy
#
# SURAJ 🍁: excited for it, feeling happy 😄
#
# 🍀 ADARSH: No they didn't ,, but I am sure these motherfuckers surprisely come
#
# Hit very hard like never before
#
# 🍀 ADARSH: Yesss !! Me too
#
# 🍀 ADARSH: I can feel the burn
#
# SURAJ 🍁: i m in tution,bye
#
# 🍀 ADARSH: Head out,,,byeee
#
# 🍀 ADARSH: Would you love to head to see rooms
#
# Anpya seen 1 , cost is 2000 per bed
#
# Will negotiate and if they refuse will find others then
#
# SURAJ 🍁: yaa tomorrow
#
# SURAJ 🍁: You deleted this message
#
# SURAJ 🍁: 👍🏻
#
# 🍀 ADARSH: Another place is available where rent is 1500 & light bill 150 ₹
#
# 🍀 ADARSH: Near kle
#
# SURAJ 🍁: its fine then
#
# 🍀 ADARSH: Can I call you know foe tmrw adjustments
#
# 🍀 ADARSH: For*
#
# 🍀 ADARSH: Now*
#
# SURAJ 🍁: yep
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Abey 🤍de why did u paid 20 anyway
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: mf
#
# SURAJ 🍁: my mom is here lovde
#
# SURAJ 🍁: call you later
#
# 🍀 ADARSH: Yes sir !!
#
# SURAJ 🍁: i have fucked up here
#
# 🍀 ADARSH: For what fantastic purpose
#
# 🍀 ADARSH: !?
#
# SURAJ 🍁: tell you later
#
# 🍀 ADARSH: Boyyyy would you send me a pic of that pant ....so I could sleep better
#
# 🍀 ADARSH: 😁🤭
#
# SURAJ 🍁: no
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: 😅
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Even without updates the laptop is drinking net like water...
#
# Is there any reasons you can think of !?
#
# SURAJ 🍁: no
#
# 🍀 ADARSH: Tf
#
# SURAJ 🍁: bhenchod
#
# 🍀 ADARSH: Well !! What the hell !!
#
# SURAJ 🍁: 😂
#
# 🍀 ADARSH: Ohh man !! One punch man !!
# That thing is hilarious 🔥⚡🎺
#
# 🍀 ADARSH: Cool af 💯❄️
#
# 🍀 ADARSH: ..
#
# 🍀 ADARSH: https://youtu.be/WqxuR-pz19M
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: nan ki hech adavo
#
# 🍀 ADARSH: Photonyag hang kansatavo
#
# 🍀 ADARSH: Will see live
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: bhencho
#
# SURAJ 🍁: we should not leave talking english btw ,we are getting pace in it ,lets just continue it😤
#
# 🍀 ADARSH: Yess !! Indeed 🌬️
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: I will stand with u in all times my man .....
#
#
#
# I have no words
#
# 🍀 ADARSH: You are the legend !!
#
# SURAJ 🍁: no words ,to tell you,we will just show the world our determination and goodness
#
# SURAJ 🍁: the fuckups you are facing are the one which are making you tuff and hard, nothing is going to stop us from achieving what we want! just we are the tuffest mother fuckers mind-it keep my words
#
# SURAJ 🍁: if you are feeling pain then i can tell how good and kind you are from inside,i don't give flying fuck about her,only i care about is you my man,just dont lose ur kindness it has nothing to do with it,i will be there with you tillllllllll...... theeeee............... end................
#
# SURAJ 🍁: having you..feels like god is helping me through you ..
#
# 🍀 ADARSH: You are the one 🤍
#
#
# Dumb fcking msgs cannot describe neither your support nor my feelings ......💯
#
# 🍀 ADARSH: Get ready
#
# 🍀 ADARSH: Elloooo
#
# SURAJ 🍁: https://youtu.be/4aE58wbXdqU
#
# SURAJ 🍁: https://youtu.be/uULy2rc6YDc
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Hey mf
# Your consistency & focus towards your learning truly inspired me...
#
#
# Today I watched the scheduled blockchain with more interest than before
#
# 🍀 ADARSH: Thanksss mannn
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: there is more to come ,mark my words😁🦾
#
# SURAJ 🍁: 🥳🥳🥳🙌🏻🙌🏻🙌🏻
#
# 🍀 ADARSH: ✈️
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Download 50 shades of grey
#
# 🍀 ADARSH: Right nowwww
#
# 🍀 ADARSH: ....
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: https://youtube.com/c/takeUforward
#
# SURAJ 🍁: call maad
#
# SURAJ 🍁: class mugyantlr
#
# SURAJ 🍁: e
#
# SURAJ 🍁: bhai avlakki kettig kottaleno ro chodimagal
#
# 🍀 ADARSH: Bring a new nail cutter pls, I will pay for it , just don't forget
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: 😄🔥🤍
#
# 🍀 ADARSH: Bhai recharge mugdeti
#
# 🍀 ADARSH: Call madoo
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: ❤️de call recieve madooo
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: You deleted this message
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: ✈️⚠️🎺⚠️🎺⚠️🙆🏻‍♂️⚡✨⚡🥲🥱🤍😄✨🙆🏻‍♂️
#
# SURAJ 🍁: bhai ni uta madir na madeni uta
#
# SURAJ 🍁: chasma bitt hogi la
#
# SURAJ 🍁: hach call
#
# SURAJ 🍁: https://www.cs.usfca.edu/~galles/visualization/Search.html
#
# SURAJ 🍁: binary search animation
#
# SURAJ 🍁: 8 ka call maad
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: Hi,
#
# I have found the best free resource to prepare for product companies - Amazon, Microsoft etc interview.
#
# Check out Striver's SDE Sheet: https://bit.ly/3zquqSu
#
# Everything you need for structured interview prep for free.
#
# SURAJ 🍁: https://takeuforward.org/interviews/most-trusted-90-days-roadmap-to-placement-guaranteed/
#
# 🍀 ADARSH: Awesome broo 💯 will discuss today eve
#
# 🍀 ADARSH: On the way
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: https://youtube.com/shorts/rZz8M5J6PTg?feature=share
#
# SURAJ 🍁: https://youtu.be/QX3iigjsqoA
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: akshay ga abs adav atto🤣 6 adav att helatidd ivatt🤣🤣
#
# 🍀 ADARSH: 😅🔥🔥🤣
#
# SURAJ 🍁: call mad
#
# SURAJ 🍁: https://youtu.be/220TpHgDfvs
#
# 🍀 ADARSH: Oooo bhaii 😂😂😂😂✈️✈️✈️🔥🔥
#
# SURAJ 🍁: https://youtube.com/shorts/_KJM_Q9LW2E?feature=share
#
# 🍀 ADARSH: 😅😂
#
# SURAJ 🍁: https://youtu.be/gLIbgAVADD0
#
# SURAJ 🍁: https://youtu.be/M2NDQOgGycg
#
# 🍀 ADARSH: Ok
#
# 🍀 ADARSH: https://www.instagram.com/tv/CaH55o0pCaA/?igshid=MDJmNzVkMjY=
#
# 🍀 ADARSH: Gtr
#
# 🍀 ADARSH: ..
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: nina hacho
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: Missed video call
#
# 🍀 ADARSH: Missed video call
#
# 🍀 ADARSH: Missed voice call
#
# 🍀 ADARSH: Missed video call
#
# 🍀 ADARSH: Missed voice call
#
# SURAJ 🍁: .
#
# 🍀 ADARSH: Bhai room key Anup kade illandra Pooja kade kodo
#
# 🍀 ADARSH: 719
#
# SURAJ 🍁: ok
#
# SURAJ 🍁: madideni nod
#
# 🍀 ADARSH: I didn't got any msg ,check again
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Done
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: 🔥🔥🔥
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: nali exam da tension aiti gappo😂
#
# 🍀 ADARSH: Sari
#
# SURAJ 🍁: watermelon tinnuhang anasatrtyo...
#
# 🍀 ADARSH: I got 1 full for 25 😁
#
# 🍀 ADARSH: Pineapple 🍍 25 🤟🏼
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: 💦
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Houd lakoo
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: gut college
# akatsuki lite
#
# SURAJ 🍁: git
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Awesome broo 😲🔥 in our clg nobody even knows it :|
#
# SURAJ 🍁: bhai navu maadod itttttooooooooooooo
#
# 🍀 ADARSH: Why not for the next time
#
# SURAJ 🍁: 💯💯💯💯💯💯ni one punch man aagbahud itt e sala
#
# 🍀 ADARSH: 😂😂
#
# 🍀 ADARSH: Clg barti
#
# 🍀 ADARSH: !?
#
# SURAJ 🍁: ill
#
# 🍀 ADARSH: WT the hell
#
# 🍀 ADARSH: Aram aglilla
#
# 🍀 ADARSH: !?
#
# SURAJ 🍁: ni elli adi eeg
#
# 🍀 ADARSH: Room
#
# SURAJ 🍁: sakageti anime nodateni
#
# 🍀 ADARSH: Sari
#
# 🍀 ADARSH: Room ka barti !!
#
# 🍀 ADARSH: ?
#
# SURAJ 🍁: na ni manig hogi att tildinni
#
# 🍀 ADARSH: Ig edk
#
# SURAJ 🍁: ivatt ratri
#
# 🍀 ADARSH: Yup alright
#
# 🍀 ADARSH: Bhai i need help with number systems
#
# SURAJ 🍁: which subject bhai?
#
# 🍀 ADARSH: Missed voice call
#
# SURAJ 🍁: ✨️ FOR PAID PROMOTIONS: @DarKCroXX
#
# 👆 Message @DarKCroXX only for paid promotion.
# https://t.me/Kaguyasama_sama_Love_is_War
#
# SURAJ 🍁: 2nd episode benki
#
# 🍀 ADARSH: I will see
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Bro screw job , money , girls .... I can leave the rest of my life happily here raising buffalos 🤣💯🌈
#
# 🍀 ADARSH: ...
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: After that whatever the program may be , after i run its just telling damn you java
#
# 🍀 ADARSH: Small problems irritate me a lot bro
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: bhai change that bot to adarsh
#
# SURAJ 🍁: try by Changing
# bot -> Adarsh
# main -> adarsh
#
# 🍀 ADARSH: Yes it worked bro
#
# 🍀 ADARSH: Thanks
#
# 🍀 ADARSH: btW kaguya is 💥
#
# 🍀 ADARSH: I don't have net , so i will once I come there
#
# SURAJ 🍁: 🙌🏻
#
# SURAJ 🍁: roomnyag idra chatri togond baa nand
#
# 🍀 ADARSH: Well alright
#
# 🍀 ADARSH: Bro where are u !!?
#
# SURAJ 🍁: lab
#
# SURAJ 🍁: dost ivatt chatri togond ba ,munjane na iskoteni
#
# 🍀 ADARSH: Bhai ivat na baratill , av Rahul bandan
#
# 🍀 ADARSH: Avn kade kottirten
#
# SURAJ 🍁: ok avn number kalsir
#
# 🍀 ADARSH: Nan avg kottirten, call recieve mad
#
# SURAJ 🍁: ha👍🏻
#
# 🍀 ADARSH: Rahul Darshan Dost.vcf (file attached)
#
# SURAJ 🍁: https://youtu.be/8MmMm2-kJV8
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: bhai yavare class kundratirakill andra hel na 1 ra mata free aden
#
# SURAJ 🍁: 1.50 mata
#
# 🍀 ADARSH: Com to kallege
#
# SURAJ 🍁: voke
#
# 🍀 ADARSH: Huttu habbada shubhashayagalu 🤍 suryaoo 🌈✨
#
# You are 22 now 😆
#
# SURAJ 🍁: bro 22 and broke also😂😂😂
#
# btw thank you for wishes😂
#
# 🍀 ADARSH: MC alumni talk anta pa. Class illa
#
# 🍀 ADARSH: Ina horag idra lib baroo
#
# SURAJ 🍁: bhai manyag adeni na ,en helud ittu??
#
# 🍀 ADARSH: Bhai assignment send pls
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: https://youtu.be/SenClIIneMI
#
# 🍀 ADARSH: https://music.youtube.com/watch?v=0ghpJJXy66E&feature=share
#
# 🍀 ADARSH: https://music.youtube.com/watch?v=PGZjbGN-rsU&feature=share
#
# SURAJ 🍁: https://music.youtube.com/watch?v=DNmrYiRU8AM&feature=share
#
# SURAJ 🍁: meaning🙌🏻🙌🏻🙌🏻🙌🏻🙌🏻🙌🏻🙌🏻🙌🏻🙌🏻
#
# 🍀 ADARSH: Fucked up reality!!
# Reject modernity!!
# Embrace masculinity!!
# 💥✈️
#
# SURAJ 🍁: 😂😂
#
# SURAJ 🍁: https://youtu.be/Ap1JfdawpVA
#
# SURAJ 🍁: watch video🤣🤣🤣🤣🤣
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Thanks to you bro !! I solved next greater elements without seeing, but with a few mistakes
#
# 🍀 ADARSH: 💥🔥
#
# 🍀 ADARSH: .
#
# 🍀 ADARSH: Bhai malkondi en ecchar adi
#
# 🍀 ADARSH: Call madod itt
#
# SURAJ 🍁: bhai akash kle dovnda 10lack package select aat
#
# SURAJ 🍁: product based company
#
# SURAJ 🍁: avng algorithms adu enu barodill
#
# 🍀 ADARSH: Wtf
#
# 🍀 ADARSH: Hengooo bhaiii
#
# 🍀 ADARSH: ...!!? 😲
#
# 🍀 ADARSH: https://www.tcs.com/careers/TCSFresherHiringYoP2023
#
# 🍀 ADARSH: Ivat java class baro , naav hind kunt DSA discuss madonu
#
# SURAJ 🍁: eeg edni na
#
# SURAJ 🍁: We invite you to YPT.
# Let's study hard together!
#
# Group name - Study Legends2022/23
#
# Invite link -
# https://invite.yeolpumta.com/re1r
#
# SURAJ 🍁: Daily life of high school boys
# https://t.me/Daily_life_of_high_school_boys
#
# SURAJ 🍁: 1st episode 🤣
#
# 🍀 ADARSH: Ok i will
#
# 🍀 ADARSH: Bro i finished naruto
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: 😱😱😱😱😱
#
# SURAJ 🍁: bhai
#
# 🍀 ADARSH: Bhai sry roo
#
# 🍀 ADARSH: Urag idde , call recieve madak aglilla
#
# 🍀 ADARSH: What's the matter ??
#
# SURAJ 🍁: en illo bhai😂,hanga hacchinni
#
# SURAJ 🍁: https://youtu.be/kICh_d6tHQk
#
# bhai his feelings 🙌🏻
#
# 🍀 ADARSH: Wait
#
# 🍀 ADARSH: Driven 💯✈️
#
# 🍀 ADARSH: Hoyyiiieee
#
# SURAJ 🍁: ha
#
# SURAJ 🍁: alli room daag kle du library du book adav avn ond swalp safe id
#
# 🍀 ADARSH: Ell adavoo
#
# 🍀 ADARSH: Ir  ig nalind tough aiti avg madod , amel nodten bhai
#
# SURAJ 🍁: yavagare nod,ott elli kaldu andra atta,adka helini
#
# SURAJ 🍁: https://music.youtube.com/watch?v=c4KCPpVWx0E&feature=share
#
# 🍀 ADARSH: Alright
#
# 🍀 ADARSH: https://youtu.be/v9BclXHp9XI
#
# A Bible video 💯
#
# 🍀 ADARSH: Watch full
#
# SURAJ 🍁: afterwards,i slept till now ,have to study 2 subs
#
# 🍀 ADARSH: Bhai rutuja yando jote full hachkond Nadu kunt triple ride hodlo
#
# SURAJ 🍁: aki tull hada😂 auti sullimagl hatr bido akinna😂😂 innond swalp divsdaag manyag gottakketi madvi maadi kalastar akin chappal le badad😂😂
#
# SURAJ 🍁: aunty*
#
# 🍀 ADARSH: Yupp broo
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: hairstyle maadteni gapp ivn gate
#
# 🍀 ADARSH: Alright 👍
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: ellindra hudkyadatiro
#
# 🍀 ADARSH: Av obb iddo same nin gate na 😂🤣 insta olag
#
# SURAJ 🍁: 😂 bhai avr chand adaro na illo😂😂
#
# 🍀 ADARSH: Fuuuk you
#
# SURAJ 🍁: bhai tcs interview yavag togotar?m
#
# SURAJ 🍁: area mydata, data, readwrite ; allocates area in RAM with name mydata
# number DCD 0
# ; allocates 4 bytes in RAM with label number.
# area mycode, code, readonly ; allocates area in ROM with name mycode
# export __main
# ; label __main is exported so that
# ;startup_lpc17xx.s can access it.
# __main ENTRY
# ; entry point into the assembly code
# MOV R0, #0x00
# ; counter for number of Zeros
# MOV R1, #0x00
# ; counter for number of ones
# MOV R2, #32
# ; counter for number of rotations
# LDR R3, =number
# ; copy address of label number into register R3
# LDR R4, [R3]
# ; copy content pointed by R3 into register R4
# again
# RORS R4, #1
# ; rotate the content of R4 to right by one bit, carry
# ;flag is updated.
# BCC label0
# ; branch to label0 if the carry is reset/cleared
# ADD R1,#0x01
# ; increment the counter for number of ones
# B label2
# ; branch to label2
# label0
# ADD R0,#0x01
# ; increment the counter for number of zeros
# label2
# SUBS R2,#0x01
# ; decrement the counter for number of rotations
# BNE again
# ; goto next rotation if the value of R2 is not zero
# END
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: What is this bro !? 😅
#
# SURAJ 🍁: bhai pc ga kalsak kalsinyo,😂 nan mute maado whatsappdaga
#
# 🍀 ADARSH: Yeah whatever, i use whatsapp rarely as there is nothing to do with it...you can carry on
#
# SURAJ 🍁: bhai busy adi en?
#
# SURAJ 🍁: bencho
#
# 🍀 ADARSH: Bhai illoo
#
# 🍀 ADARSH: Nali na aiti namd final phase
# Nang gott irakkilla avnvn
#
# 🍀 ADARSH: Matt beligge jaldi barbek adk
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: kett teli hadtaro clg dora,nale phase mugisko chandhang ameli matadonu togo
# gn
#
# 🍀 ADARSH: Yeah bro !! For sure 💯
#
# SURAJ 🍁: bro can you just tell me OTP ,i forgot my password so for recovery i put your gmail as secondary gmail,you wil receive one OTP ,send me that OTP please
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: https://youtu.be/vTnwD5wtCb0
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: congratulations bro🥳🥳🥳🔥5000 dollars
#
# 🍀 ADARSH: Yeah i seen by all the friends messages, that guy's dumb idiotic scams ..
#
# SURAJ 🍁: https://www.amishrakefight.org/gfy/
#
# i will send him this link
#
# 🍀 ADARSH: Sure 💯
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Well done mannn... Keep watching over him 😄
#
# 🍀 ADARSH: En madati
#
# SURAJ 🍁: uta
#
# 🍀 ADARSH: Ig madini
#
# 🍀 ADARSH: Bhai ninne Alli ad hanagi iddu
#
# 🍀 ADARSH: Adk call madatini na
#
# SURAJ 🍁: oh
#
# 🍀 ADARSH: 120 per one , so i left
#
# SURAJ 🍁: irli bid
#
# 🍀 ADARSH: Bhai avg kannada olag msg mado
#
# 🍀 ADARSH: Nodunu en madtan
#
# SURAJ 🍁: hadsi maga adan bido
#
# SURAJ 🍁: byare desh dov av
#
# SURAJ 🍁: bhai adi en room dag
#
# SURAJ 🍁: ?
#
# 🍀 ADARSH: Illlooo
#
# SURAJ 🍁: ok
#
# SURAJ 🍁: bhai areef 42gears ga select aagidan gott aatu?
#
# 🍀 ADARSH: Illa roo
#
# 🍀 ADARSH: Heng select ada !?enu !?
#
# 🍀 ADARSH: Bsdk ninu hakoo Ella ec branch ka bandiddu
#
# SURAJ 🍁: ha bhai ella hakateni
#
# 🍀 ADARSH: https://youtube.com/playlist?list=PLY3DFj1jjj0URoyHOnxuau6l0EgzOtoHI
#
# 🍀 ADARSH: https://youtube.com/playlist?list=PLY3DFj1jjj0WozOC8-XRbm2sRQ1YhrLBe
#
# 🍀 ADARSH: Bhai aptitude ka kelatiddi la , tugo ro
#
# Ning jasti opportunities and companies bartav on campus  CS and EC davrigi
#
# Prepare well and crack the opportunities well 💯💥
#
# All the best man 💫💯🤍
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: 🙌🏻
#
# SURAJ 🍁: bhai matadud mugyantlr phone hach
#
# 🍀 ADARSH: Yeah Bhai i will
#
# 🍀 ADARSH: Sachin is on the line , it will take a bit time
#
# SURAJ 🍁: ha araam hach
#
# SURAJ 🍁: bsdk
#
# 🍀 ADARSH: 😂
#
# 🍀 ADARSH: Sry man !!
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: en hadshi makl adar le pa ,ond aadmyal ond company baratav
#
# SURAJ 🍁: avnoun register maadud bejar aageti
#
# 🍀 ADARSH: Bsdk Ning baratav lavde
#
# 🍀 ADARSH: Namg baranilla 😭😭
#
# 🍀 ADARSH: Patna job hidi
#
# 🍀 ADARSH: Nangu ond hidsakke 😅
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: louda ella 5 lach du adav
#
# 🍀 ADARSH: https://youtube.com/shorts/gcKrthWI2fk?feature=share
#
# 🍀 ADARSH: Tate kaka 😅 thug life forever 💯
#
# SURAJ 🍁: 😂😂shut the fuck up
#
# 🍀 ADARSH: https://youtube.com/shorts/wrYUUAzgd3g?feature=share
#
# 🍀 ADARSH: Last one 😁
#
# SURAJ 🍁: gay ka matt adka en linko😂🤣🤣🤣
#
# 🍀 ADARSH: He calls everyone gay , who is not masculine and hardworking
#
# 🍀 ADARSH: ..
#
# 🍀 ADARSH: One piece 🔥
#
# SURAJ 🍁: 😂😂nodakatttiiiiiii?
#
# 🍀 ADARSH: Yeah booiiii , avnvn confidence andra loofy 💥
#
# 🍀 ADARSH: Bsdk
#
# SURAJ 🍁: enole😂?
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Will see tomorrow 😉
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: mother fucker gud ni8
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: bro you are topper 😱😱
#
# 🍀 ADARSH: Yeah yeah bro !! I am going bang all your m f ing records and make 11 cgpa and freak out all sirs 🤣✈️🌀
#
# SURAJ 🍁: bencho nale na la pakka exam?
#
# SURAJ 🍁: 9.30 ga
#
# 🍀 ADARSH: Illooo
#
# 🍀 ADARSH: Nale na adra 9.30 ka illa
#
# SURAJ 🍁: bsdk ett ka aiti mattttttttttt
#
# 🍀 ADARSH: 9.30 ka illa , 9.30 ka adav
#
# SURAJ 🍁: maaaaaaaa keeeeee chodeyyyyyyyyyyy
#
# 🍀 ADARSH: 😤
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: See you harivat
#
# SURAJ 🍁: be here
#
# 🍀 ADARSH: Yeah
#
# 🍀 ADARSH: Answers
#
# 🍀 ADARSH: !?
#
# SURAJ 🍁: tadi
#
# 🍀 ADARSH: Bhai unsolved anaateti
#
# 🍀 ADARSH: Bhai code msgado
#
# 🍀 ADARSH: I am about to bust
#
# SURAJ 🍁: dost same here
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: today night out atleast till 2am
#
# 🍀 ADARSH: Indeed !! Or i will fail !! Choice is ours
#
# 🍀 ADARSH: I hope you are alive over there !!!
#
# SURAJ 🍁: 💯
#
# 🍀 ADARSH: Still alive !?
#
# SURAJ 🍁: indeed mf
#
# 🍀 ADARSH: That's my man 💥
#
# SURAJ 🍁: bhai anjiki baratetyoooo
#
# SURAJ 🍁: bhai na malkoteni
#
# SURAJ 🍁: tata
#
# 🍀 ADARSH: Bouyyeee
#
# 🍀 ADARSH: This will happen tomorrow for me
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: bhai gand mardega exam
#
# SURAJ 🍁: ooooo meri jaaaan
#
# echr adi en bhai😂?
#
# 🍀 ADARSH: Booooosssssaaaaaddddddddkkkkkkkk
#
# 8==============D
#
# SURAJ 🍁: doat na fail agtenyooooooooooooooo
#
# SURAJ 🍁: s*
#
# SURAJ 🍁: dost echr adi?
#
# 🍀 ADARSH: Yeah ... But not anymore from now , cause i have to catch a bus soon morning
#
# 🍀 ADARSH: Hiiiiioooo
#
# SURAJ 🍁: ulalallalle lele lo
#
# 🍀 ADARSH: Zombie mf
#
# 🍀 ADARSH: Ell adirooo bsdk
#
# 🍀 ADARSH: Hey I think your purpose might be *TEACHING*
#
# SURAJ 🍁: ha i like teaching but not sure that its purpose 😅,fuck that shit,lets read for exam
#
# 🍀 ADARSH: Yuuuuuuppppo
#
# 🍀 ADARSH: 💯
#
# 🍀 ADARSH: Bhai en madatiroo
#
# SURAJ 🍁: 😂bhai maatadud mugit ill?
#
# 🍀 ADARSH: 🤍de adi en !?
#
# SURAJ 🍁: ha ro 🖤do
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Kaise ho bhoyyyy !?
#
# SURAJ 🍁: bhai 1 module skip
#
# 🍀 ADARSH: Clg booo
#
# 🍀 ADARSH: Bhai non conventional energy yar re tugondira kelo , nim dept , nam dost ga bekagidav
#
# SURAJ 🍁: You deleted this message
#
# SURAJ 🍁: yaaru illo
#
# 🍀 ADARSH: Oh shit
#
# SURAJ 🍁: bosdike java odun baaaaa
#
# 🍀 ADARSH: 🤍de yeah
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: bhai photo hodyak barteti en Questions gold?
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: https://drive.google.com/file/d/1AFxoI88GkaB5d-BF8hys9cfY4-hv9Hgf/view?usp=sharing
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Bhai tcs final exam mail bandaiti , 28th aug
#
# SURAJ 🍁: nang ina bandillllllll
#
# 🍀 ADARSH: Abbeyyy bsdkkkk id mechanical assessment antooooooooooooo
#
#
#
# Ltts davr da
#
#
#
# Bsd makl
#
#
#
#
# Mechanical en shanta barudillo nang
#
# SURAJ 🍁: 🥳 mechanical topper💪🏻
#
# 🍀 ADARSH: Oooo bhai mujhe kanti me leke maro
#
# SURAJ 🍁: 😂😂😂😂
#
# 🍀 ADARSH: Bhai band screen share madira , internal error annatetyooo
#
# 🍀 ADARSH: Open agvalt hadsi magabd
#
# SURAJ 🍁: from now onwards lets start talking in English once again
#
# SURAJ 🍁: bro try ,n ask others who r giving exam
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: till 7 you can enter anytime
#
# 🍀 ADARSH: No mfs are telling anything
#
# SURAJ 🍁: check whether you ate clicking on right link
#
# SURAJ 🍁: are*
#
# 🍀 ADARSH: Yes bro i checked both the emails they sent
#
# 🍀 ADARSH: Both are telling the same thing
#
# SURAJ 🍁: then i guess ,its their problem
#
# SURAJ 🍁: send me the link on telegram
#
# 🍀 ADARSH: Ok wait
#
# 🍀 ADARSH: I am re-entering
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: its opening
#
# SURAJ 🍁: next page to this is not opening i guess
#
# 🍀 ADARSH: Yup
#
# 🍀 ADARSH: I called them and she said , its server problem as huge no. Of students are opening at the same time
#
# 🍀 ADARSH: And she said to login after about 10 minutes
#
# SURAJ 🍁: then you keep on trying,it will open
#
# SURAJ 🍁: wooh
#
# 🍀 ADARSH: Yeah , will do that
#
# SURAJ 🍁: bro it will waste ur lots of time
#
# 🍀 ADARSH: Yeah but there is no other way
#
# SURAJ 🍁: after completing it ,make sure you read 3 starting modules
#
# 🍀 ADARSH: LT should be wise and design a website which handles such intensity
#
#
# Instead of servicing to other companies
#
# Idiots 🤣
#
# 🍀 ADARSH: Sure of that
#
# 🍀 ADARSH: Even if at the cost of 1 nights sleep
#
# SURAJ 🍁: 😂😂😂
#
# 🍀 ADARSH: Bhai  LT davr hsm adarooo
#
#
# Inna open agvalt avrvn tull
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: seriously.....,bro u read java
#
# 🍀 ADARSH: Yup and my friends are also facing same issue
#
# 🍀 ADARSH: Bhai av suprit omme matadskont band bitto
#
#
# Direct horag hakir bhai
#
# You are not authorised ant heli
#
# Just solved 6 basic questions and I am out 😣
#
# SURAJ 🍁: oh brooo
#
# SURAJ 🍁: You deleted this message
#
# SURAJ 🍁: tcs is on 21
#
# 🍀 ADARSH: Mine 28th
#
# 🍀 ADARSH: Prepare well from tomorrow only
#
# SURAJ 🍁: what to prepare?
#
# SURAJ 🍁: apti?
#
# 🍀 ADARSH: Yeah that's it
#
# 🍀 ADARSH: Quantitative aptitude
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: https://youtube.com/playlist?list=PLY3DFj1jjj0URoyHOnxuau6l0EgzOtoHI
#
# SURAJ 🍁: tq ,i will study 👍🏻
#
# SURAJ 🍁: You deleted this message
#
# 🍀 ADARSH: Madarchouuuuuuuuuuuuuuuuu
#
# 🍀 ADARSH: Bhai prepinsta prime tugollunu enoo !?
#
# 🍀 ADARSH: Bhai I forgot you are going to shravan's room 🤣
# No need to study.... Above stuff
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Surya accenture exam hengoo
#
# 🍀 ADARSH: Dear Candidate, We regret to inform you that we will not be able to proceed with your candidature based on your scores in our assessments. Good luck for your future endeavors!
#
# 🍀 ADARSH: Bhai na relatives manyag adeni roo
#
# SURAJ 🍁: bro ......heading to level 2 dsa🥳🥳🥳🥳🥳🥳🥳🥳
#
# 🍀 ADARSH: Yeah !! Do it mann...
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Suryaoo ..
# My resume is hyped so
# Bhai pls CV edit madi kod la
#
# Nan ning list kalsten en en madod ant ond page olag
#
# 🍀 ADARSH: ..
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: 😁😁i know you might be busy
# It helps a lot for me for upcoming companies bhai...so i request pls do it for me
#
# 🍀 ADARSH: Bhai tcs mail adu bandeti en
#
# SURAJ 🍁: no man
#
# 🍀 ADARSH: Alright , insta dag nodidni , adk kelini
#
# 🍀 ADARSH: What resources to use for learning  front end !?
# I did few recursion probs today
# It still takes a lil time ...
# What abt u !?
#
# 🍀 ADARSH: Just text no calls
#
# SURAJ 🍁: angela u and for perfection youtube
#
# SURAJ 🍁: i am doing project ,for tcs
#
# SURAJ 🍁: on front end
#
# SURAJ 🍁: solved 4 dsa question
#
# 🍀 ADARSH: Sure , do well...
# That's awesome 💯
#
# SURAJ 🍁: bhai you should follow code with harry also
#
# 🍀 ADARSH: Sure I will
#
# SURAJ 🍁: https://youtube.com/playlist?list=PLu0W_9lII9ahR1blWXxgSlL4y9iQBnLpR
#
# best course available on internet for javascript right now
#
# 🍀 ADARSH: Ok I will see
#
# 🍀 ADARSH: Bro from which video sorting videos start
#
# SURAJ 🍁: time and complexity playlist
#
# 🍀 ADARSH: And what about angela course
#
# Is it youtube or what
#
# 🍀 ADARSH: Ok
#
# SURAJ 🍁: firstly dont go there
#
# SURAJ 🍁: start with 1 hour html
#
# SURAJ 🍁: videos
#
# 🍀 ADARSH: Ok the thing is unfortunately laptop olag 2 hani majgi biddav
#
# So till that I have to only watch videos
#
# 🍀 ADARSH: Where is that 😁
#
# 🍀 ADARSH: Sure I will
#
# SURAJ 🍁: means html in 1 hour videos of utube
#
# 🍀 ADARSH: Ok ok thanks ...I will
#
# 🍀 ADARSH: B
#
#
#
#
#
#
#
#
# Sdk ...
#
# SURAJ 🍁: hello😁
#
# 🍀 ADARSH: How was interview !?/ & when was it actually 😆
#
# SURAJ 🍁: time hasn't come yet, i forgot everything which i read
#
# 🍀 ADARSH: How is development!?
#
# 🍀 ADARSH: Fuck that , how are you btw !?
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: from when you are coming to college?
#
# SURAJ 🍁: slowly slowly getting better in it
#
# 🍀 ADARSH: Ok its been a long time , let me tell you even if it bores you or whatever....
#
#
# I wasn't serious at dsa before
# But since past week or 10 days , i m slowly putting in the effort or at least understanding & watching videos well
#
# I might be a lot behind you, I agree , but I hope I will catch up with u in a few months...
#
# I am not into dev yet as my as a few things need to be fixed
#
#
# Thanks for guiding me through !! I got into the path well
#
#
# Getting rejected by 5 companies sucks , but standing & preparing for big fights always rocks
#
# As I don't have pass & don't have money too 😆 , I guess I will appear after dasara
#
# But I will come one day to make admission , I will inform you
#
# & thanks for everything my bro 🙏🤍..!!
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: 🥳🥳🥳🥳🥳🥳bhai lets continue this till we get into company,lets c who the mother fucker has dare to stop us
#
# 🍀 ADARSH: Indeed !! I'm with u ⚡
#
# 🍀 ADARSH: For the first time in my life I wrote a logic for a easiest problem which works
#
# But due to syntax somehow messed it up 😁 just happy for trying 1st time...
#
# 🍀 ADARSH: & btw where to slove problems in leetcode !?
#
# 🍀 ADARSH: This also in leetcode
#
# SURAJ 🍁: search for problem name and type leetcode in google,you will get
# firstly solve easy ones
#
# SURAJ 🍁: you will not get all the problems of sumit malik there
#
# SURAJ 🍁: only most important problems will be there on leetcode
#
# 🍀 ADARSH: Ok bro , I will
#
# 🍀 ADARSH: My laptop's sound has gone for some reason , I tried everything
#
# But I am doing my things except video and audio
#
# 🍀 ADARSH: Hii suryaoo....
# Bhai nanu front end start madbek madeni
# Angela course heng purchase madod en !!?
#
# En pepcoding web dev !?
# Codewithharry !?
# Apna clg !?
#
# Reply as quick as possible pls... I need guidance ...I hope you help 🙏
#
# SURAJ 🍁: maadbyad
#
# 🍀 ADARSH: Matt !?
#
# SURAJ 🍁: youtube ,watch whichever you feel easy,html is easy
# first complete that one
#
# 🍀 ADARSH: Ok sure
#
# SURAJ 🍁: apna clg,code with harry and pepcoding all are good
#
# 🍀 ADARSH: Ok alright , I will start right now
# Thanks...🙌🏻
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: 🙌🏻🤍🔥🔥🔥🔥
#
# SURAJ 🍁: heng marks hakidar eno ro😂🙌🏻🙌🏻🙌🏻
#
# 🍀 ADARSH: Bhai awesome
#
# 🍀 ADARSH: Sry wasn't able to pick call
# Tell me about it
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: class Solution {
# 	public String minWindow(String s, String t) {
# 		// shortifying
# 		int slen = s.length();
# 		int tlen = t.length();
#
# 		// preparing t string frequency map
# 		HashMap<Character, Integer> tfmap = new HashMap<>();
# 		for (int i = 0; i < t.length(); i++) {
# 			char x = t.charAt(i);
# 			tfmap.put(x, tfmap.getOrDefault(x, 0) + 1);
# 		}
#
# 		// iterating through s string
# 		int i = 0, j = 0;
#
# 		// map for s string character frequencies
# 		HashMap<Character, Integer> sfmap = new HashMap<>();
#
# 		int match_count = 0;
# 		String min_substring = "";
# 		int min_ss_len = Integer.MAX_VALUE;
# 		while (i < slen) {
# 			// putting ith element to sfmap
# 			char x = s.charAt(i);
#
# 			// checking whether its in t string
# 			if (tfmap.containsKey(x) == true) {
# 				sfmap.put(x, sfmap.getOrDefault(x, 0) + 1);
#
# 				// checking whether it was usefull put
# 				int xcount = sfmap.get(x);
# 				int pcount = tfmap.get(x);
# 				if (xcount <= pcount) {
# 					match_count = match_count + 1;
# 				} else {
#
# 				}
#
# 				// checking whether all characters of t are in s
# 				if (match_count == tlen) {
# 					// taking that substring out
# 					String sub_string = s.substring(j, i + 1);
# 					int sslen = sub_string.length();
#
# 					// checking whether its minimum length substring
# 					if (sslen < min_ss_len) {
# 						System.out.println(sub_string + " 1");
# 						min_substring = sub_string;
# 						min_ss_len = sslen;
# 					} else {
#
# 					}
#
# 					// moving j forward
# 					while (j <= i) {
# 						// removing/reducing jth element from sfmap
#
# 						char c = s.charAt(j);
# 						if (sfmap.containsKey(c) == true) {
# 							int ccount = sfmap.get(c);
#
# 							// if its 1 then remove else reduce
# 							if (ccount == 1) {
# 								sfmap.remove(c);
# 							} else {
# 								sfmap.put(c, sfmap.get(c) - 1);
# 							}
# 							j++;
# 							// checking still the substring is valid one
# 							if (sfmap.containsKey(c) == false) {
# 								match_count = match_count - 1;
# 								break;
# 							} else {
# 								// p - preffered
# 								int new_c_count = sfmap.get(c);
# 								int p_count = tfmap.get(c);
# 								if (new_c_count >= p_count) {
# 									// taking that substring out
# 									String sub_string2 = s.substring(j, i + 1);
# 									int sslen2 = sub_string2.length();
#
# 									// checking whether its minimum length substring
# 									if (sslen2 < min_ss_len) {
# 										System.out.println(sub_string2 + " 2");
# 										min_substring = sub_string2;
# 										min_ss_len = sslen2;
# 									} else {
#
# 									}
#
# 								} else {
# 									match_count = match_count - 1;
# 									break;
# 								}
# 							}
# 						} else {
# 							j++;
# 							// taking that substring out
# 							String sub_string3 = s.substring(j, i + 1);
# 							int sslen3 = sub_string3.length();
#
# 							// checking whether its minimum length substring
# 							if (sslen3 < min_ss_len) {
# 								System.out.println(sub_string3+ " 3");
# 								min_substring = sub_string3;
# 								min_ss_len = sslen3;
# 							} else {
#
# 							}
#
# 						}
# 					}
# 				} else {
#
# 				}
# 				i = i + 1;
# 			} else {
# 				i = i + 1;
# 			}
# 		}
#
# 		if(min_ss_len == Integer.MAX_VALUE){
# 			return "";
# 		} else {
# 			return min_substring;
# 		}
# 	}
# }
#
# SURAJ 🍁: bhai id heng crct bardinni eno ro 😂 nanga nambak agvalt
#
# 🍀 ADARSH: You are 💯💯⚡
#
# SURAJ 🍁: bhai rehn do😂
#
# 🍀 ADARSH: Yeah yeah .... I had no better lines than that soo
#
#
# Don't worry , I am lot dumber a lot of the times to say things
#
# SURAJ 🍁: oh bhai u got my point right 🙌🏻 epic
#
# SURAJ 🍁: https://music.youtube.com/watch?v=cnRB2CgUpSw&feature=share
#
# 🍀 ADARSH: Hey bro I sincerely asking you for a help..
#
#
# I am getting to know better what it takes to get into product based companies & as you know it takes a lot of time for me ( btw am not leaving XD )...
#
# As you also know the condition is must for me to get a job in hand
#
# I am requesting you to inform me about any off campus jobs & help me clear the exams of those companies....it will a huge help if u say yes
#
# Btw no way in the hell I am  leaving DSA, always right behind you
#
# But you know why i want one job ...pls let me know if u will
#
# SURAJ 🍁: once i meet you i will tell
#
# 🍀 ADARSH: YOOOHOHOHOHOHOHO
#
# 🍀 ADARSH: Bhai forgot to ask
#
# 🍀 ADARSH: When is exam
#
# SURAJ 🍁: bhai i gave aptitude test its cleared
#
# you have to help me in interveiw
#
# 🍀 ADARSH: Sure
#
# SURAJ 🍁: hi
#
# 🍀 ADARSH: Hlo
#
# SURAJ 🍁: bro, till what time you have class?
#
# 🍀 ADARSH: 2.20
#
# 🍀 ADARSH: Why
#
# 🍀 ADARSH: Is it earlier
#
# 🍀 ADARSH: !?
#
# SURAJ 🍁: no ,i dont know the timing
#
# 🍀 ADARSH: Dont worry man , I will leave with 2.30 bus
#
# SURAJ 🍁: ok👍🏻
#
# SURAJ 🍁: bhai 4pm
#
# SURAJ 🍁: come as soon as possible
#
# SURAJ 🍁: To join the meeting on Google Meet, click this link:
# https://meet.google.com/mqk-ibgu-wfy
#
# Or open Meet and enter this code: mqk-ibgu-wfy
#
# SURAJ 🍁: bhai tomorrow 11.30 tcs digital interview
#
# 🍀 ADARSH: Ooooo mannnnn !!!
#
# 🍀 ADARSH: Is there a need of me or what !?
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: yes bro , i think we can fix my mobile on my laptop screen some how
#
# 🍀 ADARSH: Hey bhai text pls
#
# 🍀 ADARSH: Umm it's tough for me to come but
# Make a proper plan , I will come
#
# 🍀 ADARSH: I just reached home an hour ago
#
# 🍀 ADARSH: ...
#
# SURAJ 🍁: okay
#
# SURAJ 🍁: i think its not easy to cheat
#
# 🍀 ADARSH: Why so !?
#
# SURAJ 🍁: because they will ask to write code also
#
# SURAJ 🍁: bro its fine if dont come, i think interview we have to give by our own
#
# 🍀 ADARSH: Ok I won't come , but if u think u need , I will come
#
# SURAJ 🍁: no its fine dont come
#
# 🍀 ADARSH: Ok then
#
# 🍀 ADARSH: Hey bro how did ur interview go !?
#
# SURAJ 🍁: i have answered most of questions,but dont know what will happen
#
# 🍀 ADARSH: Ok don't worry then , hope it will get cleared , did they asked to code !?
#
# SURAJ 🍁: yes
#
# SURAJ 🍁: palindromic number🤣 coded it it 3 mins
#
# SURAJ 🍁: in*
#
# 🍀 ADARSH: https://youtu.be/pmj9gF7H_lQ
#
# Bhai my humble request 😂😂 id ond full nodo bhai
#
# SURAJ 🍁: ha nodteni
#
# 🍀 ADARSH: Bhai valid parenthesis , without watching solution 3 test case accept agiddunooo , submit hodyana wrong bant
#
# SURAJ 🍁: just there will be some minor edge cases ,see the test case for which answer is failing ,try to understand it
#
# 🍀 ADARSH: First it was passing 3 test cases , after it was 74 , then I saw solution , there was a genius  who wrote it in few lines near 10
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Are they nuts !? I mean hsm randi makl bhai , kehna kya chahte hai bhosadiwale
#
# SURAJ 🍁: 😂
#
# SURAJ 🍁: be ready for this situation i.e when rutuja gets placed😂 advice from me
#
# 🍀 ADARSH: Yeah !! Actually 😂😂 I don't care about that bitch anymore !!
# Btw I mean I really forgot her 🤣 lmao..
#
# I don't think I ever seen her in months , neither offline nor onlone
#
# SURAJ 🍁: ha same here but it can happen like she get placed before you
#
# SURAJ 🍁: thats why i told
#
# 🍀 ADARSH: Just DSA X friends X family X  anime
#
# SURAJ 🍁: 🥳🥳🔥🔥🤯😁
#
# 🍀 ADARSH: Yeah I really appreciate...
# Soo I took precautions & therefore imagined she getting a job few months ago , my subconscious knew it
#
#
# But guess what !! Even if she becomes prime minister of india or north korea I ain't gonna give a shit 😂
#
# She is a bitch & no profession , no highest package is going to change that
#
#
# & we brothers who are studs also is not going to change , no matter what situation arrives
#
# I got your back & I hope the same ...
#
#
# Just kick ass , help people & have fun , screw everything else 🤙🏼💥
#
# 🍀 ADARSH: & specifically screw those damn bitches ....once a bitch forever a bitch
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: once a bitch forever a bitch,epic ,i think one piece is really doing magics😂💥
#
# 🍀 ADARSH: 😅🤣
#
# SURAJ 🍁: i want to take my own monitor to company 😂,i dont know why cimpanies dont allow it
#
# SURAJ 🍁: o*
#
# 🍀 ADARSH: How do they !?
# If u use a shortcut which pastes any code from a keyword 🤣
#
# Then they would die
#
# 🍀 ADARSH: Hey I don't know you have completely seen grand blue or not
#
#
# But there are not many around us like those 2 lori & kohei
#
# I mean from deep inside they are good but outside they are always competing like hell , ripping apart each of themselves... And because of that they were growing
#
#
# Just a random though while studying !! Don't bother
#
# SURAJ 🍁: i have not seen that completely
#
# 🍀 ADARSH: Moron
#
# SURAJ 🍁: 🤣 i will see uf you want ne 2 see
#
# SURAJ 🍁: i*
#
# SURAJ 🍁: me*
#
# 🍀 ADARSH: 😂 no bro , it's no big deal , just to simply tell
#
# They both were friends who id always competing in everything , mocking & fighting each other
#
# But they had good intentions inside , that's what I was trying to say
#
# 🍀 ADARSH: Is* line 3 error
#
# SURAJ 🍁: you are telling like compiler😂
#
# 🍀 ADARSH: Yuuuuup
# Finishing the level 1 today
#
# SURAJ 🍁: ya we can compete,congrats for  🥳🥳 finishing level 1
#
# 🍀 ADARSH: Videos.length - 2
#
# SURAJ 🍁: heavy........
#
# 🍀 ADARSH: 🤣🤣
#
# 🍀 ADARSH: See ya later bro !! I must finish
#
# Keep grinding , keep growing
# Bye 💗
#
# SURAJ 🍁: oy
#
# SURAJ 🍁: bhai matrix olag diagonally traverse madak barvato nangaaaaaaa🤯
#
# 🍀 ADARSH: I am not wise but
# Is it by any chance I++ & j++
#
# 🍀 ADARSH: I mean I+ -> this direction
#               J+ -> this direction
#
# 🍀 ADARSH: Lol I don't think so , sry about that
#
# SURAJ 🍁: bsdk sry yak kelati😂
#
# SURAJ 🍁: i got it
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Yeah type errors whatever , who cares
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Bhai leetcode davrn mukli hadak bek hsm , ella method bhai avaru byare na adav , matt nav svant barkobek pa
#
# SURAJ 🍁: avru solution nodbyad,avru ni ond 500 problems bidsantle familiar aagateti
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: easy iddiddu hudkyadi bidsateni😂😂
#
# 🍀 ADARSH: No I am not seeing but , while solving correct answers are also wrong
#
# Anyway building from scratch makes it good 💯😂
#
# 🍀 ADARSH: Yeah I have to do too
#
# SURAJ 🍁: na maadov maad ningu easy aagateti
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: merge two sorted list tough aityole paila easy iddiddu bids array ameli strings du
#
# 🍀 ADARSH: Don't mind but
#
# I am trying to do in which I am a little strong , so that i can drive towards yours later
#
# I will solve those
#
# SURAJ 🍁: .
#
# 🍀 ADARSH: 😂😂😂😂 its easy af bro
# May be you've mistaken it for different problem though 🙄
#
# 🍀 ADARSH: No probs , I am on your words
#
# SURAJ 🍁: ha might be😂 o yes the tuf one was median of two sorted  arrays
#
# 🍀 ADARSH: Yes yesss
# I haven't even seen that 😁
#
# SURAJ 🍁: lets see who solves more probs a day
#
# SURAJ 🍁: 😁
#
# 🍀 ADARSH: Alright man , see ya
#
# Cause I take 2hrs for a prob
# As I mess things up
#
# 🍀 ADARSH: You are cruel..
#
# SURAJ 🍁: 😂😂🤣
#
# 🍀 ADARSH: & let's face cruelty tomorrow for sure
#
# 🍀 ADARSH: As I spent my day doing those bastard's assignments
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: https://music.youtube.com/watch?v=E9T78bT26sk&feature=share
#
# SURAJ 🍁: https://youtu.be/X34ZmkeZDos
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: https://leetcode.com/problems/diagonal-traverse/description/
#
# SURAJ 🍁: https://youtu.be/oCqkVZVPOe8
#
# 🤣 watch this
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: yeah its fine ,u r duing gr8
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: You are damn epic
#
#
# & the thing is they only select fools , who know how to charm their cobra , bastardsssss.......
#
# SURAJ 🍁: Accenture is selecting people who are potential candidates for blowjob in Accenture
#
# 🍀 ADARSH: 😂 ohh bro , I was reading seriously until potential candidates..
# & then there you are with a banggg 🤣
#
# SURAJ 🍁: 😂😂
#
# 🍀 ADARSH: Hey solve no.1662
#
#
# The amount of joy it comes after solving a problem completely on own is another level
#
#
# All credits to you !!
# Although the problem I solve are kiddish enough , but in the beginning I think I am doing at least a little good
#
# 🍀 ADARSH: Thanks man!!
#
# SURAJ 🍁: ok i will solve 1662 ,have to read fir exams
#
# 🍀 ADARSH: Ok , sure
#
# SURAJ 🍁: you do 345 its possible by you
#
# SURAJ 🍁: any other qn u solved?
#
# 🍀 ADARSH: no bro , some relatives and stuff
# Some habba & stuff
# & evening nali exam & stuff
#
# But I will try atleast 1 today somehow
#
# SURAJ 🍁: ha dint break the streak
#
# SURAJ 🍁: dont
#
# 🍀 ADARSH: Sure I won't
#
# SURAJ 🍁: till we get into faang 😂 streak should be there
#
# 🍀 ADARSH: The thing it's not gonna break even after we get in
#
#
# Cause initially I was doing it for job
# But now it includes fun too , I really enjoy doing those , 🥲even though i solved only a few easy probs 😂 lol
#
# SURAJ 🍁: yes in life, if we run behind love we will not get love,if we run behind money we will not get it thats how life works,so its better to enjoy the journey rather than aiming at something which we dont know afterwards satisfies us or not.
#
# 🍀 ADARSH: Agreed !!
#
# SURAJ 🍁: i want you also to come with me to banglore with me😂 aage ka baad me dekhenge
#
# 🍀 ADARSH: For what freaking purpose 😂!?
#
# SURAJ 🍁: mthr fukr, yav job hudadru banglore nlka hogbekla
#
# SURAJ 🍁: hidadru*
#
# 🍀 ADARSH: Ohh like that , yeah definitely I will 👍🏻👍🏻💯💯
#
# 🍀 ADARSH: Nowadays I doubt that you are practicing fast typing even on whatsapp too
#
# SURAJ 🍁: 😂🙌🏻
#
# 🍀 ADARSH: 🤣🤣 yeah keep doing whatever you want !!
# That's how it works
#
# I was pretty busy today in habba stuff , so I will read till evening
#
# SURAJ 🍁: https://leetcode.com/problems/maximum-product-of-three-numbers/
#
# SURAJ 🍁: https://youtu.be/B6CjoCEhk90
#
# 🍀 ADARSH: I follow him , he is awesome 💯
#
# 🍀 ADARSH: Bhai wtf !! If you really want to pay so bad , then just pay actual amount
#
# I doubt that I didn't even spent 60 on you
#
# 🍀 ADARSH: 😅
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: select easy or medium in tag,and click on acceptance, then click on settings and turn on the show tags,and start solving
#
# SURAJ 🍁: solve high acceptance problems first
#
# 🍀 ADARSH: Ok
#
# SURAJ 🍁: u r doing great🙌🏻 happy for u
#
# 🍀 ADARSH: Thank you 💯🤍
#
# SURAJ 🍁: are you coming to college tomorrow?
#
# 🍀 ADARSH: Noo
#
# 🍀 ADARSH: Tomorrow is rajyotsav soo
#
# SURAJ 🍁: 👍🏻
#
# SURAJ 🍁: akash was doing ankering so
#
# 🍀 ADARSH: Ok
#
# SURAJ 🍁: leetcode is down
#
# 🍀 ADARSH: I was solving and just
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: same here
#
# 🍀 ADARSH: Bro i am just started solving problems a week ago , I can't solve a lot of them
#
#
# But this is way more interesting
#
# SURAJ 🍁: still its not coming
#
# 🍀 ADARSH: I thought I have a bad connection
#
#
# No problem , I will go swim 😁
#
# SURAJ 🍁: i listen to this in background
#
# SURAJ 🍁: https://youtu.be/vLEek3I3wac
#
# SURAJ 🍁: its open i guess(leetcode)
#
# 🍀 ADARSH: Brings back memories , when I was in diploma 🤣 & in depression
#
# 🍀 ADARSH: Lets see
#
# 🍀 ADARSH: Bhai not able to open problems
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Lol ! I am such a fool
# Forgot to increment 😁
#
# 🍀 ADARSH: Anyway with this method it fails at case 88 , where these guys give you a linked list of
# 100000 size
#
# So I used arraylist , now it beats 95%
#
# SURAJ 🍁: 😂 i saw your messages now, 🙌🏻 i was also solving probs
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Awesome
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: bhai i m in home😅
#
# 🍀 ADARSH: 😐
#
# 🍀 ADARSH: Bhai about kth largest element in array
# If I use sort it beats more than 80 % in both time & space.
#
# If I use heap than it rarely beats 50%
#
# But everyone is talking like heap is the best approach , what's all thing about !?
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: https://leetcode.com/problems/sum-of-all-odd-length-subarrays/discuss/2780813/Fastest-solution-(100)-different-method-no-formulae
#
# 🍀 ADARSH: Congratulations for minfi broo 🥳💯👍🏻🤍💥
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: what is this bhai?😅
#
# 🍀 ADARSH: From a yt video
# For iman gadzi his friend sent this to him
#
#
# So I felt its worth sending you the same message
#
# 🍀 ADARSH: Are you coming tomorrow to clg !?
#
# 🍀 ADARSH: I was coming so I asked !!?
#
# SURAJ 🍁: yes
#
# 🍀 ADARSH: https://youtu.be/LL98HP2hWhs
#
# Both of them in one vid
#
# For problems check their playlist
#
# 🍀 ADARSH: https://youtu.be/kCLFSVft1W0
#
#
#
# Watch it when u want to take a rest ,, this guy is the one I was talking about with iman gadzhi
#
#
# A young millionaire who wants to build dream house like you
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: download bereal i m on it
#
# 🍀 ADARSH: Sure!! See you there
#
# 🍀 ADARSH: Sent the request
#
# SURAJ 🍁: accepted
#
# SURAJ 🍁: iman gadzhi is playing on his viewers
#
# 🍀 ADARSH: Just got to know in his last video 🥲
# Never thought he comes to that point after all that he did...
#
# SURAJ 🍁: i knew that he was planning for something
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: i also when first started with web dev, did the same thing😂 i tried to have insta blue tick with > million followers
#
# 🍀 ADARSH: 😂😂😂😂💯🔥🔥
#
# SURAJ 🍁: bhai i think you are emotionally mature
#
# 🍀 ADARSH: Let's move on forward  together!!
#
# SURAJ 🍁: exam da odati?
#
# 🍀 ADARSH: Well !! They released kantara
# Soo I watched it 😁
# , now I will code , tomorrow I will read
#
# SURAJ 🍁: if you were in ec branch...we would have read together...
#
# 😁👍🏻
#
# 🍀 ADARSH: Bhai if u have time or free , check out 141 leetcode and if u understand that please explain problem statement to me
#
# SURAJ 🍁: ok wait
#
# SURAJ 🍁: yes i understood it,if you want ...u call call me ,i will explain the meaning of question to you
#
# SURAJ 🍁: can*
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Hey bro
# ...
# Bachelor or Masters in Computer Science
# Programming experience with at least one modern language such as Java, C++, or C# including object-oriented design
# Advocate for solutions to technical challenges, articulating schedule/ risk/ quality trade-offs                                      https://unstop.com/job/software-development-engineer-ctt-cis-amazon-583609?utm_source=Freshercareers-Telegram&utm_medium=Affiliates&utm_campaign=Amazon08012023
#
# SURAJ 🍁: man i wrote some extraordinary code today..
#
# https://leetcode.com/problems/max-points-on-a-line/solutions/3020830/java-epic-solution-handled-some-edge-cases/
#
# 🍀 ADARSH: Awesome 💯
#
# 🍀 ADARSH: Suri bhai wanted to ask and tell something , although its not big deal or its not the right thing or time
#
#
#
# But how the hell do you think that I am even worth being something important to share your thoughts or someone you can have as a friend
#
# Like don't you ever think that i am nothing , I never helped you in anything that matters really , neither I am good at something  nor I am wise , I am of no use to you anything
#
# I just feel that sometimes in future you are going to realize that I am of no value , I feel you are overvaluing me and I am afraid that I am nothing
#
# 🍀 ADARSH: Sometimes I feel I am not worth your time , thoughts & importance
#
# I am sending this not because that I am depressed or something like that but because of what i am realizing
#
#
# Btw nothing wrong with my mood , I am totally happy 😆
#
# SURAJ 🍁: ok then you are in good mood then...
# let me tell you then..why you worth
# You know.. i have told you many times that.."i can see through people"..
# I have seen many people but they have something achivement tagged to their name ...but no clue of hard work..
# you are the only person i know, who works like hell and has achieved nothing (outer visible trash achievements)
#
# i know what you have achieved...
# you have purest thoughts when it comes to thinking of others (there is no sign of negetive thinking to others)
#
# you are disciplined and never complaining man when it comes to responsibility.
#
# the world most of the times fails to see where you have backed yourself to help others.(goodness can't be seen by bad eyes)
#
# the attachment of you with your parents in an inspiration for me (its more than getting placed in google and no connection of feelings with parents) for me.
#
# i have modeled you in many sectors, let me tell you
# the changes in me because of you:
#    i never thaught that i have ego before meeting you, i never knew what is politeness, i never knew that there are men working hard than me and have nothing got in return..
# there are specifically n things which i like about you..
# once you take some decision, you never come to me saying bro it cant be done by me, you always give your best
#
# i learnt how to read less and pass exams from you
# , how to not worry about dumb things,
# you where not between child me and now me
# ,you never asked anybody in your downtimes which i like the most, you present what others want from you,
#
# what i believe..god will do...in future
# you will become smart and most intelligent person, you will becomes stringer than ever, you will enjoy like nobody does, there will be no situation which can fear you, everybody will start to understand you and i m sensing that..that day is nearer,
#
# what i think is...once you taste the success..then there is nobody who can stop you...you need nobodies advice ..on your own you will rise like nobody..
#
#
#
# in that all.....
# what i am doing is just taking the characters which i can adopt from you... understanding them only takes 5-6 months..but i love them.
# btw you are the first person i didn't compete with and admired.
#
# 🍀 ADARSH: Lol ! Again I have no words
# But i don't want to explain your understanding and friendship by fancy words & your contribution to my life
#
# You have grown such a fine man in the past months ! Can't measure it with anything
#
# Love to give back someday what you have given to me
# ( although its impossible )
#
# Lol ! Screw it ,,, lets study
# Don't text back for a while
# 😂
#
# Man.. I am awesomest  , just to have friends who are family  👪 I can die peacefully 💯
#
# SURAJ 🍁: Infosys Off Campus Drive 2023 for Freshers | 2020/2021/2022 Batch | Across India | Last Date : 13th January 2023
#
# Job Role : Specialist Programmer
# Qualification : BE/BTech/ME/MTech/MCA/MSc
# Batch : 2020/2021/2022 Batch
# Salary : INR 9.5 LPA
# Job Location : Across India
# Venue Location : Virtual(Online)
# Last Date : 13th January 2023
#
# To Apply:
# https://bit.ly/Infosys-Recruitment-Program
# If it is not useful to you...
# Share this in your circle, this create someone's career
#
# 🍀 ADARSH: Its only uptill 22 batch broo
#
# 🍀 ADARSH: Sure I will
#
# SURAJ 🍁: oh shit
#
# 🍀 ADARSH: What shit
#
# SURAJ 🍁: its not for 23 batch
#
# 🍀 ADARSH: Exactly what I said 😁
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: ya
#
# 🍀 ADARSH: https://youtu.be/6Y-V_8UJ_xU
#
# SURAJ 🍁: https://youtu.be/nCD2hj6zJEc
#
# SURAJ 🍁: https://youtu.be/DAYszemgPxc
#
# 🍀 ADARSH: The video's first comment satisfied me for a while 🪶
#
# SURAJ 🍁: music is so awesome, addicted to it
#
# SURAJ 🍁: ...
# PROMISE ME THAT, YOU WILL GIVE ME NECK TO NECK FIGHT IN EVERY FUCKING THINGS FROM NOW ONWARDS
#
# SURAJ 🍁: today my whole passport procedures completed, i will help u in your time
#
# 🍀 ADARSH: Man... Thanks for that ! 💯
#
# 🍀 ADARSH: That's the most wonderful way to grow
# Yeah i will , but from 31st jan 😁
#
# SURAJ 🍁: https://youtu.be/XsROO8jt0CA
#
# 🍀 ADARSH: 🍷🗿
#
# SURAJ 🍁: i am seeing both of us in some big tech company, well settled and lost ourself in journey of our self interests, endeavouring and guiding the buds... and standing strong to whatever it is....🥀
#
# 🍀 ADARSH: Indeed man !!
#
# If I don't disappoint your mood for a while 😁
# I am seeing my fucked up face in the examination hall after seeing this exam's question paper XD
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: https://vtu.ac.in/en/nptel-online-courses/
#
# SURAJ 🍁: lets do this courses they are valuable
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: https://youtu.be/giLlKR4qNzE
#
# SURAJ 🍁: https://youtu.be/po6kjouyxXg
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: Finished demon slayer 😁
#
# SURAJ 🍁: 🔥🍁
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Extrawesome but simple 🔥
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: 🌼🤍
#
# 🍀 ADARSH: Hey bro initially i was wanting to code only for the sake of job
#
# But now I am highly fucking wanting to code because of pure passion & interest
#
# I am not doing as exams interfere , trust me i am gonna code nuts after exams
# Regardless of fucking job ✊
#
# SURAJ 🍁: yes.. it will benifit you lot, because i.e what you are lacking off,
# if you develop interest...you will never see the time its taking and that is where the magic happens..time goes slow, your speed of learning goes high and differentiating base of knowledge will be formed..may you retain your interest in coding in future also 😇
#
# 🍀 ADARSH: Yeah ! Absolutely .....!!
# after multiple times losing interest , interruptions & all that , now I can really understand my coding process & learning curve
#
# I might be slow , i had some gaps , but the real fun lies in going straight ahead ! & that is what my nature is !!
#
# Thank you for being with me throughout the process & most of all ,  thanks for keeping  the trust on me even though i really play dumb a lot or you can say majority of the times lol !! XD
#
# 🍀 ADARSH: Bhai ad nptel innond sala idra bido , hoyt avnvn ello ada
#
# SURAJ 🍁: https://vtu.ac.in/en/nptel-online-courses/
#
# 🍀 ADARSH: Thanks
#
# SURAJ 🍁: https://youtu.be/tXDzgaPoJQI
#
# 🍀 ADARSH: 🌞
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Me telling you is like a student guiding his guide
#
# Anyway if I have to try to explain , i definitely will
#
# 🍀 ADARSH: And about that phone call , I was not wanting to talk about that but here anyway
#
# You are sometimes really a lifesaver for me , you can see my blindspot , initially while on the call my ego tried to block your words of truth
#
# Then later when i see , those were simple truths that I failed to realize & just like that I was off the path long ago
# ..the truth bombs were needed & you supplied them at the right time
#
# I was soo sunk in myself that I can't even see myself....you have my gratitude
#
#
# & about meditation
# Day 1.I did it for a fewer minutes , no change
# Day 2. I am getting to get familiar & understand why I am slowly get off the path later
#
# & rest I will be exploring soon
#
# 🍀 ADARSH: ..
#
# SURAJ 🍁: before anything else....
# while meditating....
#  sit straight and there is one tying i have found dont know how to tell it in chat ,i will explain u on next meet.
#
#  chant for your god (for beginners i think its best to chant for not devine gods but admiring great bhakta*s i chant for "Basavanna" he is my idol and sign for devine purity and unlimited energy source for expectation-less hard work)
#
# while chanting calm your mind ,observe your actions and thoughts were they are going... focus on chant count try to not to think any thing else...(try to not to forget the count throughout the meditation) keep chanting as slow as possible
#
# it will calm you to another level ,you will smile like you never did till today..
#
# may god bring light in our life and also in life of all good hard workers 🙏🏻 may this goodness never vanish 🌸
#
# 🍀 ADARSH: Thank you 🌿
#
# SURAJ 🍁: https://www.clearias.com/memory-techniques/
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: durga software channel videos,very much knowledgeable
# sir is awesome,see once when u r free
#
# SURAJ 🍁: to learn java its good
#
# 🍀 ADARSH: sure , I will check it out
#
# SURAJ 🍁: Dear Students,
# This is to notify that our placement team is planning for few placement drives exclusively for unplaced students probably in the month of March.
# And for these drives probably in the last week of February we are planning to have placement training from Company Expertees.
#
# We request you to fill this 👇🏻 form so that we can get the exact count of students who wish to surely appear for these drive.
#
#  *PLACED STUDENTS ARE NOT ALLOWED*
#
# https://forms.gle/3Mp9FdHLXEePCNDp7
#
# SURAJ 🍁: Do the needful till 1st February.
#
# SURAJ 🍁: nim sir kalsidar en nodri nim branch ga
#
# 🍀 ADARSH: Kalsilla avr
#
# 🍀 ADARSH: Thanks for this
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: today is last date
#
# 🍀 ADARSH: Ok
#
# 🍀 ADARSH: Thank you
#
# I will apply as soon as I reach home
#
# SURAJ 🍁: Man bday completed in McDonald's
#
# 🍀 ADARSH: How was it !?
#
# SURAJ 🍁: rich wibe nothing else😅
#
# 🍀 ADARSH: Hey bro can you tell me about passport
#
# SURAJ 🍁: yes,call me at the time of applying
#
# 🍀 ADARSH: sure !!!
#
# 🍀 ADARSH: https://youtu.be/qPDbNYcCXi8
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Facts !
# Can I assume these are from chanakya ! ?
#
# SURAJ 🍁: yes chanakya the legend
#
# 🍀 ADARSH: Hey brother .. I will call you evening
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: According to chanakya
#
# He compares a person who don't have a guru & self taught , to a woman who had baby without her husband
#
# Because that knowledge can be misleading & if anyone asks both the person & a woman , who caused this they can't answer
#
# (may be I am 100% wrong )
#
# 🍀 ADARSH: The low level people want money
#
# Middle level want money & a little reputation& respect (honour)
#
# Nobles (those who are respected in society ) only cares about their integrity & respect (honour)
#
# 🍀 ADARSH: One should either enjoy or hardwork ( do one thing )
#
# Which means one should not ruin enjoyment if they don't want to work further
#
# If one wants to work hard & move up , they must focus on that & should not care about enjoyment
#
# 🍀 ADARSH: ( I may be 100% absolutely wrong )
#
# SURAJ 🍁: ok thanks 👍🏻
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: 😁🙏🏼 jai
#
# 🍀 ADARSH: I don't know what endorse is actually
#
# But you did & i thought its a good thing , & I did the same XD
#
# SURAJ 🍁: https://www.overleaf.com/project/63e36caf231234689069fcc2
#
# SURAJ 🍁: this is better
#
# https://www.overleaf.com/latex/templates/deedy-cv/bjryvfsjdyxz
#
# 🍀 ADARSH: Thank you 🙌🏻🤍
#
# SURAJ 🍁: NEW...AI APPS ARE AMAGING 🔥🔥🔥🔥🔥🔥🔥🔥🔥
#
# 🍀 ADARSH: Yesss
#
# 🍀 ADARSH: Uta madatidde adk call recieve madlilla , I have to go tomorrow for internship to clg
#
# So I hope we can speak later
#
# SURAJ 🍁: came to know that my brother is earning 15lack monthly,
# what I earn in 30 days...my brother earns in 1 day, inspired bu his success and aim and mindset 💪 hoping that we both also achive way more than these all
#
# SURAJ 🍁: "Never settle Never bound"  lets embrace the journey with all we can give 🗽
#
# 🍀 ADARSH: Really amazed tp hear someone in your family circle do that
# Lets enjoy and respect the process ...🙌🏻
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: was planning for MS in grmany/ Japan, but my father is advising me to take 4-5 years experience in tata
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Yeah this I got it
#
# 🍀 ADARSH: But this i didn't get very well
#
# SURAJ 🍁: what tell..
#
# SURAJ 🍁: important exams and opportunities after BE
#
# 🍀 ADARSH: Ohh alright
#
# 🍀 ADARSH: According to my inosuke head , you solved the problem in just 135 ms which beats almost 99% of other submissions
#
# SURAJ 🍁: 🥳as I expected,You are wrong
#
# the amazing thing was,
# there are same percentage of people in every milisecond solutions,
# means
# 1.59% people have solved it in 325ms
# 1.59% people have solved it in 311ms
# 1.59% people have solved it in 408ms
# 1.59% people have solved it in 130ms
# ..
# ..
# so on
#
# 🍀 ADARSH: Ahhhhh ....as always 🙌🏻
#
# SURAJ 🍁: not always..,some times
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: 🔥💪🥳 i think you are in love with linked lists
#
# 🍀 ADARSH: Nah its just striver's sheet
# & binary trees need recursion which I am still learning , that's why
#
# SURAJ 🍁: 🐧 i will also do more probs from today
#
# 🍀 ADARSH: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: cgpa 7.5 haaki la
#
# 🍀 ADARSH: Hu bhai select ago mata re
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: Agreed !
#
# SURAJ 🍁: how to use chatgpt
#
# SURAJ 🍁: i am not able to signup
#
# 🍀 ADARSH: I never used it
# I am going to that mech internship today
#
# SURAJ 🍁: and yesterday i did my project but failed to deploy it as its asking for credit card😅
#
# SURAJ 🍁: 😅 okay
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: Just have a glance over bosscoder academy and masters union , what do you think about them?
#
# 🍀 ADARSH: Results are out , cleared but thses mfs reduced my marks too much bro , system sucks
#
# SURAJ 🍁: man congrats 😀😀 very happy for you
#
# 🍀 ADARSH: https://results.vtu.ac.in/JFEcbcs23/index.php
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: <Media omitted>
#
# SURAJ 🍁: man i calculated sgpa in takeiteasy.com
# its showing 8.909
#
# Thanks man your technique helped me lot👍🏻🤠
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: bro don't calculate percentage using that , that calculates wrong
#
# SURAJ 🍁: whooooo😂 i also thaught,how i can get that much
#
# 🍀 ADARSH: they are the definition of many people's dreams
#
# SURAJ 🍁: not getting sleep😅
#
# 🍀 ADARSH: wanted to tell you something that resume scanners and all are sometimes useless unless you are applying for pbc's                             because my resume scored 47 points , and that chandru's resume scored 4  …..  and you know who got the call and the offer
#
# 🍀 ADARSH: reality is quite different actually , not that I am frustrated or anything like that , but facts are facts lol
#
# SURAJ 🍁: 😅🙌🏻 have no clue how this happened
#
# SURAJ 🍁: then what is it actually?
#
# SURAJ 🍁: man i have found 1 glitch
#
# 🍀 ADARSH: for me its just the line from sri krishna , do your work without ever expecting the results , rest will follow or not
#
# SURAJ 🍁: <Media omitted>
#
# 🍀 ADARSH: I m really sorry to say that I cannot understand it either
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: <Media omitted>
#
# SURAJ 🍁: Rank 3 in my division 🥳
#
# 🍀 ADARSH: You are 🔥
#
# SURAJ 🍁: thank you 🙏🙂
#
# 🍀 ADARSH: How did you hosted it 😁
#
# SURAJ 🍁: i failed to host it
#
# SURAJ 🍁: i have just sent you the html file, add some css to it
#
# 🍀 ADARSH: I am outside in a temple
#
# 🍀 ADARSH: I will do it by evening
#
# SURAJ 🍁: take 10 days , add anytime
#
# 🍀 ADARSH: Sure I will

# %%
dates = re.findall(pattern, data)
# print(dates)

# %%
df = pd.DataFrame({'user_messege' : messeges, 'messege_date': dates})
# df['messege_date']
df['messege_date'] = pd.to_datetime(df['messege_date'], format='%d/%m/%y, %I:%M %p - ')

# %%
df.rename(columns = {'messege_date' : 'date'}, inplace = True)

# %%
users = []
messeges = []
for messege in df['user_messege']:
    entry = re.split('([\w\W]+?):\s', messege)
    if entry[1:]:
        users.append(entry[1])
        messeges.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messeges.append(entry[0])

df['user'] = users
df['messege'] = messeges
df.drop(columns=['user_messege'], inplace=True)

df['only_date'] = df['date'].dt.date
df['year'] = df['date'].dt.year
df['month_num'] = df['date'].dt.month
df['month'] = df['date'].dt.month_name()
df['day'] = df['date'].dt.day
df['day_name'] = df['date'].dt.day_name()
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

period = []
for hour in df[['day_name', 'hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour == 0:
        period.append(str('00') + "-" + str(hour + 1))
    else:
        period.append(str(hour) + "-" + str(hour + 1))

df['period'] = period

# %%
df.head()
# Out:
#                  date                user  \
# 0 2022-03-20 12:25:00  group_notification
# 1 2022-03-20 12:25:00            🍀 ADARSH
# 2 2022-03-20 12:25:00            🍀 ADARSH
# 3 2022-03-20 12:26:00            🍀 ADARSH
# 4 2022-03-20 12:26:00            🍀 ADARSH
#
#                                              messege   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2022-03-20  2022
# 1                                  <Media omitted>\n  2022-03-20  2022
# 2                                  <Media omitted>\n  2022-03-20  2022
# 3                                  <Media omitted>\n  2022-03-20  2022
# 4                                  <Media omitted>\n  2022-03-20  2022
#
#    month_num  month  day day_name  hour  minute period
# 0          3  March   20   Sunday    12      25  12-13
# 1          3  March   20   Sunday    12      25  12-13
# 2          3  March   20   Sunday    12      25  12-13
# 3          3  March   20   Sunday    12      26  12-13
# 4          3  March   20   Sunday    12      26  12-13
